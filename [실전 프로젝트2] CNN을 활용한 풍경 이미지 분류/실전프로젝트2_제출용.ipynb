# %% [markdown]
# ### <b>실전 프로젝트 - CNN을 활용한 풍경(Scene) 이미지 분류</b>
#
# * 한 장의 풍경 이미지가 주어졌을 때, 어떠한 카테고리(category)에 속하는지 맞히는 <b>분류 모델</b>을 만드세요.
# * 다음의 세 가지 대표적인 CNN 모델을 실습합니다.
#     1. [LeNet (1998)](http://yann.lecun.com/exdb/publis/pdf/lecun-98.pdf)
#     2. [AlexNet (2012 NIPS)](https://papers.nips.cc/paper/2012/file/c399862d3b9d6b76c8436e924a68c45b-Paper.pdf)
#     3. [ResNet (2016 CVPR)](https://arxiv.org/abs/1512.03385)
# * 성능을 올릴 수 있는 두 가지 심화 기법을 실습합니다.
#     1. [Mixup (ICLR 2018)](https://arxiv.org/abs/1710.09412): 데이터 증진 기법의 일종으로 정확도를 높입니다.
#     2. Transfer Learning: 학습 속도와 정확도를 모두 향상시킬 수 있습니다.
# * 본 프로젝트는 <b>총 7개의 문제</b>로 구성됩니다.
#     * <b>Problem</b>이라고 명시된 부분의 소스코드만 작성합니다.
#     * <b>알아보기</b>라고 명시된 부분은 단순히 읽고 실행하면 됩니다.
#     * 단계적으로 문제를 풀어나가는 과정에서 CNN 기반의 고성능 분류 모델을 학습하는 방법을 이해할 수 있습니다.
# * (참고) 본 실습 코드에서는 빠른 결과 도출을 위해 30~50 epoch 정도만 학습합니다.
#     * 풍경 데이터셋에 대하여 완전히 학습시키기 위해서는 100 epoch 이상의 학습이 필요합니다.

# %% [markdown]
# #### <b>(알아보기) 지난 프로젝트 Review</b>
#
# * 지난 프로젝트에서는 Scene Classification 데이터셋에 대하여 간단한 기계학습 모델을 학습했습니다.
#     1. 선형 분류 모델(Linear Models for Classification)
#     2. KNN (K-Nearest Neighbors)
# * 하지만, 두 기법 모두 정확도(accuracy)가 <b>60% 미만</b>으로 낮게 나온다는 <b>한계점</b>이 존재했습니다.
# * 본 실습에서는 CNN을 이용해 정확도를 <b>최소한 90% 이상으로</b> 높입니다.
#     * 실제로 현업에서 많이 사용되는 테크닉을 이용해 최대한 정확도를 끌어올려 봅시다.

# %% [markdown]
# #### <b>Problem 1. 데이터셋 다운로드 및 분석하기</b>
#
# * [PyTorch용 Scene Classification 데이터셋 저장소](https://github.com/ndb796/Scene-Classification-Dataset-Split)
#     * 참고: [원본 Kaggle 데이터셋 링크](https://www.kaggle.com/nitishabharathi/scene-classification)
#     * 본 데이터셋은 <b>저작권이 없는(No Copyright)</b> [CC0: Public Domain](https://creativecommons.org/publicdomain/zero/1.0/) 라이센스를 따라므로, 자유롭게 변형할 수 있습니다.
# * PyTorch에서 곧바로 불러와 사용할 수 있도록 구성된 데이터셋입니다.
# * 다음의 명령어를 이용해 데이터셋을 다운로드할 수 있습니다.
#
# <pre>
# # 깃허브에서 데이터셋 다운로드하기
# !git clone https://github.com/ndb796/Scene-Classification-Dataset-Split
# # 폴더 안으로 이동
# %cd Scene-Classification-Dataset-Split
# </pre>

# %%
# 깃허브에서 데이터셋 다운로드하기
# !git clone https://github.com/ndb796/Scene-Classification-Dataset-Split 
# 폴더 안으로 이동
# %cd Scene-Classification-Dataset-Split
# Out:
# Cloning into 'Scene-Classification-Dataset-Split'...
# remote: Enumerating objects: 17038, done.
# remote: Total 17038 (delta 0), reused 0 (delta 0), pack-reused 17038
# Receiving objects: 100% (17038/17038), 136.02 MiB | 48.21 MiB/s, done.
# /content/Scene-Classification-Dataset-Split

# %% [markdown]
# #### <b>(알아보기) 데이터셋 설명</b>
#
# * 본 PyTorch용 장면(scene) 데이터셋은 17,034개의 다양한 <b>자연 경치(scene)</b> 이미지로 구성되어 있습니다.
# * 총 6개의 클래스(class)로 구성됩니다.
#
# <pre>
# 클래스 0. 빌딩(buildings)
# 클래스 1. 숲(forests)
# 클래스 2. 빙하(glacier)
# 클래스 3. 산(mountains)
# 클래스 4. 바다(sea)
# 클래스 5. 거리(street)
# </pre>
#
# * 각 이미지는 공통적으로 64 X 64 크기를 가집니다.
# * 데이터셋 폴더 구성은 다음과 같습니다.
#
# <pre>
# Dataset/
#     train/
#         buildings/
#         forests/
#         glacier/
#         mountains/
#         sea/
#         streat/
#     val/
#         buildings/
#         forests/
#         glacier/
#         mountains/
#         sea/
#         streat/
# </pre>

# %% [markdown]
# #### <b>(알아보기) 클래스별 학습 이미지 개수 출력하기</b>
#
# * 클래스별 데이터의 개수를 계산합니다.
#     * os 라이브러리의 os.listdir()를 이용하여 이미지 폴더에 존재하는 파일 이름 목록을 얻을 수 있습니다.
#     * 클래스의 개수는 6개입니다.
# * 총 학습 데이터의 개수는 13,627개입니다.
#
# <pre>
# 클래스 0. 빌딩(buildings): 2,105개
# 클래스 1. 숲(forests): 2,205개
# 클래스 2. 빙하(glacier): 2,363개
# 클래스 3. 산(mountains): 2,438개
# 클래스 4. 바다(sea): 2,224개
# 클래스 5. 거리(street): 2,292개
# </pre>
#
# * 총 검증 데이터의 개수는 3,407개입니다.
#
# <pre>
# 클래스 0. 빌딩(buildings): 523개
# 클래스 1. 숲(forests): 540개
# 클래스 2. 빙하(glacier): 594개
# 클래스 3. 산(mountains): 599개
# 클래스 4. 바다(sea): 560개
# 클래스 5. 거리(street): 591개
# </pre>

# %%
import os


classes = ['buildings', 'forests', 'glacier', 'mountains', 'sea', 'street']
train_path = 'train/'
val_path = 'val/'

print("[ 학습 데이터셋 ]")
for i in range(6):
    print(f'클래스 {i}의 개수: {len(os.listdir(train_path + classes[i]))}')

print("[ 검증 데이터셋 ]")
for i in range(6):
    print(f'클래스 {i}의 개수: {len(os.listdir(val_path + classes[i]))}')
# Out:
# [ 학습 데이터셋 ]
# 클래스 0의 개수: 2105
# 클래스 1의 개수: 2205
# 클래스 2의 개수: 2363
# 클래스 3의 개수: 2438
# 클래스 4의 개수: 2224
# 클래스 5의 개수: 2292
# [ 검증 데이터셋 ]
# 클래스 0의 개수: 523
# 클래스 1의 개수: 540
# 클래스 2의 개수: 594
# 클래스 3의 개수: 599
# 클래스 4의 개수: 560
# 클래스 5의 개수: 591

# %% [markdown]
# #### <b>(알아보기) 데이터셋 불러오기</b>
#
# * PyTorch의 <b>ImageFolder 라이브러리</b>를 이용하여 <b>자신만의 데이터셋</b>을 불러올 수 있습니다.
# * ImageFolder 라이브러리는 다음과 같이 <b>계층적인 폴더 구조</b>에서 데이터셋을 불러올 때 사용할 수 있습니다.
#     * 각 클래스명(class name)으로 된 폴더에 여러 장의 이미지가 들어가 있는 구조입니다.
#
# <pre>
# dataset/
#     class 0/
#         0.jpg
#         1.jpg
#         ...
#     class 1/
#         0.jpg
#         1.jpg
#         ...
#     ...
#     class 9/
#         0.jpg
#         1.jpg
#         ...
# </pre>
#
# * 기본적인 <b>데이터 증진(data augmentation)</b> 기법을 사용합니다.
#     * [RandomResizedCrop()](https://pytorch.org/vision/stable/transforms.html): 학습 시기에 랜덤으로 이미지의 일부를 잘라내어 특정 크기로 변형합니다.
#     * [RandomHorizontalFlip()](https://pytorch.org/vision/stable/transforms.html): 학습 시기에 랜덤으로 이미지를 좌우 반전합니다.
# * <b>정규화(normalization)를</b> 진행합니다.
#     * 일반적으로 많이 사용되는 ImageNet 데이터셋의 설정을 이용합니다.

# %%
import torch
from torchvision import datasets, transforms


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # device object

transforms_train = transforms.Compose([
    transforms.RandomResizedCrop((64, 64)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

transforms_val = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(train_path, transforms_train)
val_dataset = datasets.ImageFolder(val_path, transforms_val)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=True, num_workers=2)

print('Training dataset size:', len(train_dataset))
print('Validation dataset size:', len(val_dataset))

class_names = train_dataset.classes
print('Class names:', class_names)
# Out:
# Training dataset size: 13627
# Validation dataset size: 3407
# Class names: ['buildings', 'forests', 'glacier', 'mountains', 'sea', 'street']

# %% [markdown]
# #### <b>(알아보기) 이미지 시각화하기</b>
#
# * PyTorch로 불러온 데이터(torch.Tensor 객체)를 시각화해 봅시다.
# * Google Colab에 출력하기 위해서 NumPy 형태로 변형한 뒤에 Matplotlib을 이용합니다.
#     * torch.Tensor는 (Channel, Height, Width) 형식을 가집니다.
#     * numpy 객체는 (Height, Width, Channel) 형식을 가집니다.

# %%
import torchvision
import numpy as np
import matplotlib.pyplot as plt


# 화면에 출력되는 이미지 크기를 적절하게 조절하기
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 60
plt.rcParams.update({'font.size': 20})


def imshow(image, title):
    # torch.Tensor => numpy 변환하기
    image = image.numpy().transpose((1, 2, 0))
    # 이미지 정규화(normalization) 해제하기
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    image = np.clip(image, 0, 1)
    # 화면에 이미지 출력하기
    plt.imshow(image)
    plt.title(title)
    plt.show()


# 학습 데이터셋에서 하나의 배치를 불러와 보기
iterator = iter(train_dataloader)

# 현재 배치에 포함된 이미지를 출력하기
inputs, classes = next(iterator)
out = torchvision.utils.make_grid(inputs[:4])
imshow(out, title=[class_names[x] for x in classes[:4]])

# %% [markdown]
# #### <b>Problem 2. Convolution 연산 이해하기</b>
#
# * Convolution 연산의 동작 원리를 이해할 필요가 있습니다.
# * <b>[그림 예시]</b> 아래 그림에서는 stride가 1이고, padding이 0일 때의 Convolution 연산 예시를 보입니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <hr>
#
# * 입력 데이터의 높이: $height$
# * 입력 데이터의 너비: $width$
# * 필터의 높이: $filter\_height$
# * 필터의 너비: $filter\_width$
# * 스트라이드(stride): $stride$
# * 패딩 크기: $padding$
#
# <hr>
#
# * Convolution 연산 이후의 출력 차원은 다음과 같은 공식으로 계산할 수 있습니다. (나누기할 때 소수점 아래 버림)
#     * 출력 높이(output height) = $(height + 2 * padding - filter\\_height) / stride + 1$
#     * 출력 너비(output width) = $(width + 2 * padding - filter\\_width) / stride + 1$
#
# * <b>[문제]</b> 다음의 각 경우에 대하여 Convolution 연산을 수행한 뒤의 출력 차원을 쓰세요.
#     1. $height=32$, $width=32$, $filter\\_height=5$, $filter\\_width=5$, $stride=2$, $padding=2$일 때 → {답을 쓰세요.}
#     2. $height=64$, $width=64$, $filter\\_height=3$, $filter\\_width=3$, $stride=1$, $padding=1$일 때 → {답을 쓰세요.}
#     3. $height=16$, $width=16$, $filter\\_height=4$, $filter\\_width=4$, $stride=2$, $padding=1$일 때 → {답을 쓰세요.}
#     4. $height=60$, $width=45$, $filter\\_height=8$, $filter\\_width=5$, $stride=3$, $padding=1$일 때 → {답을 쓰세요.}
#
# * (Hint) 다음과 같은 Python 코드를 사용하여 간단히 계산할 수 있습니다.
#
# <pre>
# height = 16
# width = 16
# filter_height = 4
# filter_width = 4
# stride = 2
# padding = 1
#
# output_height = (height + 2 * padding - filter_height) // stride + 1
# output_width = (width + 2 * padding - filter_width) // stride + 1
#
# print('출력 높이:', output_height, '출력 너비:', output_width)
# </pre>
#
# * 실행 결과 예시
#
# <pre>
# 출력 높이: 8 출력 너비: 8
# </pre>

# %%
param_list=[(32,32,5,5,2,2),(64,64,3,3,1,1),(16,16,4,4,2,1),(60,45,8,5,3,1)]

cnt=0
for height,width,filter_height,filter_width,stride,padding in param_list:
  cnt+=1
  output_height = (height + 2 * padding - filter_height) // stride + 1
  output_width = (width + 2 * padding - filter_width) // stride + 1
  print(cnt, '출력 높이:', output_height, '출력 너비:', output_width)
# Out:
# 1 출력 높이: 16 출력 너비: 16
# 2 출력 높이: 64 출력 너비: 64
# 3 출력 높이: 8 출력 너비: 8
# 4 출력 높이: 19 출력 너비: 15

# %% [markdown]
# #### <b>(알아보기) Lenet 아키텍처 이해하기</b>
#
# * 기본적인 LeNet 아키텍처를 이해할 수 있습니다.
#     * Convolutional Neural Network를 최초로(1998년) 적용한 간단한 아키텍처입니다.
#     * Convolution 연산과 Pooling 연산이 사용됩니다.
# * <b>아래의 표</b>와 같은 아키텍처를 PyTorch로 구현한 것을 확인해 봅시다.
#     * 원본 논문과 완전히 동일하지는 않지만, 핵심 아이디어를 잘 표현한 아키텍처입니다.
#     * PyTorch에서는 모델에 별도로 Softmax 레이어를 두지 않고, 학습할 때 nn.CrossEntropyLoss()를 사용하는 것이 일반적입니다.

# %% [markdown]
# Layer | Type | Specification
# :-: | :-: | ---
# 1 | Input | image size: 3 X 64 X 64
# 2 | Convolution | # of kernel: 20, kernel size: 5 X 5, stride: 1, zero padding: 0
# 3 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 4 | Convolution | # of kernel: 50, kernel size: 5 X 5, stride: 1, zero padding: 0
# 5 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 6 | Fully Connected | # of neuron: 500
# 7 | Activation | ReLU
# 8 | Fully Connected | # of neuron: 6
# 9 | Softmax | 6 classes

# %%
import torch.nn as nn
import torch.nn.functional as F


class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        # → 차원(dimension): (3 x 64 x 64)
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=20, kernel_size=5, stride=1, padding=0)
        # → 차원(dimension): (20 x 60 x 60)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        # → 차원(dimension): (20 x 30 x 30)
        self.conv2 = nn.Conv2d(in_channels=20, out_channels=50, kernel_size=5, stride=1, padding=0)
        # → 차원(dimension): (50 x 26 x 26)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        # → 차원(dimension): (50 x 13 x 13)
        self.fc1 = nn.Linear(50 * 13 * 13, 500)
        # → 차원(dimension): (500)
        self.fc2 = nn.Linear(500, 6)
        # → 차원(dimension): (6)

    def forward(self, x):
        x = self.pool1(self.conv1(x))
        x = self.pool2(self.conv2(x))
        x = torch.flatten(x, 1) # 배치(batch)를 제외한 모든 차원 flatten하기
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# #### <b>(알아보기) 학습 및 평가 함수 이해하기</b>
#
# * 별도의 학습(train) 함수와 평가(validate) 함수를 작성합니다.

# %%
def train(net, epoch, optimizer, criterion, train_dataloader):
    print('[ Train epoch: %d ]' % epoch)
    net.train() # 모델을 학습 모드로 설정
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_dataloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad() # 기울기(gradient) 초기화

        outputs = net(inputs) # 모델 입력하여 결과 계산
        loss = criterion(outputs, targets) # 손실(loss) 값 계산
        loss.backward() # 역전파를 통해 기울기(gradient) 계산

        optimizer.step() # 계산된 기울기를 이용해 모델 가중치 업데이트
        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    print('Train accuarcy:', 100. * correct / total)
    print('Train average loss:', train_loss / total)
    return (100. * correct / total, train_loss / total)


def validate(net, epoch, val_dataloader):
    print('[ Validation epoch: %d ]' % epoch)
    net.eval() # 모델을 평가 모드로 설정
    val_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(val_dataloader):
        inputs, targets = inputs.to(device), targets.to(device)

        outputs = net(inputs) # 모델 입력하여 결과 계산
        val_loss += criterion(outputs, targets).item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    print('Accuarcy:', 100. * correct / total)
    print('Average loss:', val_loss / total)
    return (100. * correct / total, val_loss / total)

# %% [markdown]
# #### <b>(알아보기) LeNet 학습하기</b>
#
# * 앞서 정의한 LeNet 네트워크를 학습합니다.
# * 학습률(learning rate)을 수정해보면서 결과를 확인해 봅시다.
#     * 만약 학습률이 너무 크다면, 발산하여 손실(loss) 값이 NaN으로 나오며 학습이 안 될 수 있습니다.

# %%
import time
import torch.optim as optim


net = LeNet()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "LeNet.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 50.15043663315477
# Train average loss: 0.03964573769521458
# [ Validation epoch: 1 ]
# Accuarcy: 64.54358673319636
# Average loss: 0.030341029884460424
# Model saved! (time elapsed: 24.98266315460205)
# [ Train epoch: 1 ]
# Train accuarcy: 58.01717179129669
# Train average loss: 0.03390553557112569
# [ Validation epoch: 2 ]
# Accuarcy: 69.00498972703258
# Average loss: 0.027131090407011827
# Model saved! (time elapsed: 45.84825849533081)
# [ Train epoch: 2 ]
# Train accuarcy: 60.94518235855287
# Train average loss: 0.031945711135024445
# [ Validation epoch: 3 ]
# Accuarcy: 70.58996184326386
# Average loss: 0.0256264543547321
# Model saved! (time elapsed: 61.91415500640869)
# [ Train epoch: 3 ]
# Train accuarcy: 63.2200777867469
# Train average loss: 0.030414485617342512
# [ Validation epoch: 4 ]
# Accuarcy: 70.09098914000587
# Average loss: 0.025976574128766475
# Model saved! (time elapsed: 74.54280614852905)
# [ Train epoch: 4 ]
# Train accuarcy: 64.90056505467088
# Train average loss: 0.02923599173127402
# [ Validation epoch: 5 ]
# Accuarcy: 72.32169063692398
# Average loss: 0.024027444109526203
# Model saved! (time elapsed: 87.22838640213013)
# [ Train epoch: 5 ]
# Train accuarcy: 66.28751742863433
# Train average loss: 0.02836685000629779
# [ Validation epoch: 6 ]
# Accuarcy: 71.00088054006457
# Average loss: 0.024752618876726775
# Model saved! (time elapsed: 100.31045269966125)
# [ Train epoch: 6 ]
# Train accuarcy: 66.79386512071622
# Train average loss: 0.027679947807476193
# [ Validation epoch: 7 ]
# Accuarcy: 75.25682418550043
# Average loss: 0.021863981928334126
# Model saved! (time elapsed: 113.86869716644287)
# [ Train epoch: 7 ]
# Train accuarcy: 67.74785352608791
# Train average loss: 0.027323255010472447
# [ Validation epoch: 8 ]
# Accuarcy: 73.9653654241268
# Average loss: 0.023210945920507545
# Model saved! (time elapsed: 128.83271765708923)
# [ Train epoch: 8 ]
# Train accuarcy: 67.87994422837015
# Train average loss: 0.02716922931470988
# [ Validation epoch: 9 ]
# Accuarcy: 75.46228353390079
# Average loss: 0.02199983056213697
# Model saved! (time elapsed: 141.7506775856018)
# [ Train epoch: 9 ]
# Train accuarcy: 68.34960005870698
# Train average loss: 0.02708278406897198
# [ Validation epoch: 10 ]
# Accuarcy: 74.52304079835632
# Average loss: 0.02280591002719858
# Model saved! (time elapsed: 154.41470742225647)
# [ Train epoch: 10 ]
# Train accuarcy: 68.75321053790269
# Train average loss: 0.026279196994988926
# [ Validation epoch: 11 ]
# Accuarcy: 76.48958027590255
# Average loss: 0.02086509937829974
# Model saved! (time elapsed: 168.5303249359131)
# [ Train epoch: 11 ]
# Train accuarcy: 69.1494826447494
# Train average loss: 0.026183435152236072
# [ Validation epoch: 12 ]
# Accuarcy: 74.17082477252715
# Average loss: 0.023096361860418586
# Model saved! (time elapsed: 181.5340769290924)
# [ Train epoch: 12 ]
# Train accuarcy: 70.07411756072503
# Train average loss: 0.025527769157452078
# [ Validation epoch: 13 ]
# Accuarcy: 77.13530965658937
# Average loss: 0.020360605927342224
# Model saved! (time elapsed: 195.50551509857178)
# [ Train epoch: 13 ]
# Train accuarcy: 70.30160710354443
# Train average loss: 0.02499981716722458
# [ Validation epoch: 14 ]
# Accuarcy: 78.10390372761961
# Average loss: 0.019769886646901963
# Model saved! (time elapsed: 208.38596367835999)
# [ Train epoch: 14 ]
# Train accuarcy: 71.51977691348058
# Train average loss: 0.02485860816501789
# [ Validation epoch: 15 ]
# Accuarcy: 75.84385089521574
# Average loss: 0.021920154035738708
# Model saved! (time elapsed: 221.81910705566406)
# [ Train epoch: 15 ]
# Train accuarcy: 70.91069200851251
# Train average loss: 0.024981085864133074
# [ Validation epoch: 16 ]
# Accuarcy: 76.22541825653067
# Average loss: 0.021615306268103634
# Model saved! (time elapsed: 235.23925280570984)
# [ Train epoch: 16 ]
# Train accuarcy: 70.2282233800543
# Train average loss: 0.025026489230991066
# [ Validation epoch: 17 ]
# Accuarcy: 78.86703845024948
# Average loss: 0.01944008913948489
# Model saved! (time elapsed: 257.9734787940979)
# [ Train epoch: 17 ]
# Train accuarcy: 71.9233873926763
# Train average loss: 0.0242214104443747
# [ Validation epoch: 18 ]
# Accuarcy: 78.04520105664808
# Average loss: 0.020509400114412702
# Model saved! (time elapsed: 273.5566620826721)
# [ Train epoch: 18 ]
# Train accuarcy: 71.68122110515887
# Train average loss: 0.02426530014325231
# [ Validation epoch: 19 ]
# Accuarcy: 78.89638978573525
# Average loss: 0.019506303872885787
# Model saved! (time elapsed: 292.06419134140015)
# [ Train epoch: 19 ]
# Train accuarcy: 72.2022455419388
# Train average loss: 0.023769650366910443
# [ Validation epoch: 20 ]
# Accuarcy: 77.98649838567655
# Average loss: 0.020891311767341315
# Model saved! (time elapsed: 311.0381817817688)
# [ Train epoch: 20 ]
# Train accuarcy: 72.75996184046379
# Train average loss: 0.02358772116151097
# [ Validation epoch: 21 ]
# Accuarcy: 78.42676841796302
# Average loss: 0.019376447224742965
# Model saved! (time elapsed: 329.01921010017395)
# [ Train epoch: 21 ]
# Train accuarcy: 72.85536068100096
# Train average loss: 0.02361266816135652
# [ Validation epoch: 22 ]
# Accuarcy: 78.01584972116231
# Average loss: 0.020506686178651905
# Model saved! (time elapsed: 347.1975290775299)
# [ Train epoch: 22 ]
# Train accuarcy: 72.19490716958978
# Train average loss: 0.02370022346541792
# [ Validation epoch: 23 ]
# Accuarcy: 75.52098620487232
# Average loss: 0.022483217452046175
# Model saved! (time elapsed: 368.041042804718)
# [ Train epoch: 23 ]
# Train accuarcy: 72.95075952153812
# Train average loss: 0.023265154667730648
# [ Validation epoch: 24 ]
# Accuarcy: 79.89433519225125
# Average loss: 0.019408776735083812
# Model saved! (time elapsed: 387.4880950450897)
# [ Train epoch: 24 ]
# Train accuarcy: 72.7673002128128
# Train average loss: 0.0231426985062445
# [ Validation epoch: 25 ]
# Accuarcy: 76.40152626944526
# Average loss: 0.021432767445858463
# Model saved! (time elapsed: 404.24903178215027)
# [ Train epoch: 25 ]
# Train accuarcy: 72.67923974462464
# Train average loss: 0.023343989215646337
# [ Validation epoch: 26 ]
# Accuarcy: 78.25066040504844
# Average loss: 0.020033708010071143
# Model saved! (time elapsed: 421.1619825363159)
# [ Train epoch: 26 ]
# Train accuarcy: 73.56718279885521
# Train average loss: 0.022756951078067234
# [ Validation epoch: 27 ]
# Accuarcy: 80.12914587613736
# Average loss: 0.01856739308640234
# Model saved! (time elapsed: 435.4529390335083)
# [ Train epoch: 27 ]
# Train accuarcy: 73.91942467160784
# Train average loss: 0.022567402315286738
# [ Validation epoch: 28 ]
# Accuarcy: 77.39947167596125
# Average loss: 0.021136576570581402
# Model saved! (time elapsed: 451.111891746521)
# [ Train epoch: 28 ]
# Train accuarcy: 73.31033976663976
# Train average loss: 0.02265824918492556
# [ Validation epoch: 29 ]
# Accuarcy: 80.62811857939536
# Average loss: 0.01845656599962085
# Model saved! (time elapsed: 472.9381036758423)
# [ Train epoch: 29 ]
# Train accuarcy: 73.94143978865488
# Train average loss: 0.02265308010146878
# [ Validation epoch: 30 ]
# Accuarcy: 80.1878485471089
# Average loss: 0.018897819526040874
# Model saved! (time elapsed: 490.9848644733429)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### <b>(알아보기) 혼동 행렬 시각화하기</b>
#
# * 참고: [Seaborn.heatmap 공식 문서](https://seaborn.pydata.org/generated/seaborn.heatmap.html)
# * 각 클래스에 대하여 정확히 분류하는지 확인하기 위해 <b>혼동 행렬(confusion matrix)</b>을 생성할 수 있습니다.

# %%
# 네트워크에 데이터셋을 입력하여 혼동 행렬(confusion matrix)을 계산하는 함수
def get_confusion_matrix(net, num_classes, data_loader):
    net.eval() # 모델을 평가 모드로 설정
    confusion_matrix = torch.zeros(num_classes, num_classes, dtype=torch.int32)

    for batch_idx, (inputs, targets) in enumerate(data_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        outputs = net(inputs)
        _, predicted = outputs.max(1)

        for t, p in zip(targets.view(-1), predicted.view(-1)):
            confusion_matrix[t.long(), p.long()] += 1

    return confusion_matrix

# %%
import pandas as pd
import seaborn as sns


net = LeNet()
net = net.to(device)

file_name = "./checkpoint/LeNet.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.7801, 0.9352, 0.7660, 0.6344, 0.8714, 0.8393])
# [ 전체 평균 정확도 ]
# tensor(0.8019)

# %% [markdown]
# #### <b>Problem 3. CustomLeNet 아키텍처 작성하기</b>
#
# * 다음과 같이 LeNet 아키텍처를 변경하여 CustomLeNet을 만들어 봅시다.
#     * 커널 크기와 커널의 개수를 증가시켰습니다. (파라미터 수 증가)
#     * Fully Connected 레이어의 차원을 증가시켰습니다. (파라미터 수 증가)
#
# Layer | Type | Specification
# :-: | :-: | ---
# 1 | Input | image size: 3 X 64 X 64
# 2 | Convolution | # of kernel: 128, kernel size: 8 X 8, stride: 1, zero padding: 0
# 3 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 4 | Convolution | # of kernel: 256, kernel size: 8 X 8, stride: 1, zero padding: 0
# 5 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 6 | Convolution | # of kernel: 512, kernel size: 4 X 4, stride: 1, zero padding: 0
# 7 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 8 | Fully Connected | # of neuron: 4096
# 9 | Activation | ReLU
# 10 | Fully Connected | # of neuron: 6
# 11 | Softmax | 6 classes

# %%
class CustomLeNet(nn.Module):
    def __init__(self):
        super(CustomLeNet, self).__init__()
        # 이 부분에 소스코드를 작성하세요.
        self.conv1=nn.Conv2d(in_channels=3,out_channels=128,kernel_size=8,stride=1,padding=0)
        self.pool1=nn.MaxPool2d(kernel_size=2,stride=2)
        self.conv2=nn.Conv2d(in_channels=128,out_channels=256,kernel_size=8,stride=1,padding=0)
        self.pool2=nn.MaxPool2d(kernel_size=2,stride=2)
        self.conv3=nn.Conv2d(in_channels=256,out_channels=512,kernel_size=4,stride=1,padding=0)
        self.pool3=nn.MaxPool2d(kernel_size=2,stride=2)
        self.fc1=nn.Linear(4608,4096)
        self.fc2=nn.Linear(4096,6)

    def forward(self, x):
        # 이 부분에 소스코드를 작성하세요.
        x=self.pool1(self.conv1(x))
        x=self.pool2(self.conv2(x))
        x=self.pool3(self.conv3(x))
        x=torch.flatten(x,1)
        x=F.relu(self.fc1(x))
        x=self.fc2(x)

        return x

# %% [markdown]
# #### <b>(알아보기) CustomLeNet 평가하기</b>
#
# * 새롭게 작성한 CustomLeNet과 앞선 LeNet의 성능을 비교합니다.
#     * 파라미터가 증가한 만큼 성능 향상이 있는지 확인해 봅시다.
# * 아래 코드를 실행하여 학습 및 성능 평가를 진행할 수 있습니다.

# %%
import time
import torch.optim as optim


net = CustomLeNet()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "CustomLeNet.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 48.78549937623835
# Train average loss: 0.04088730860011912
# [ Validation epoch: 1 ]
# Accuarcy: 64.22072204285296
# Average loss: 0.03151360044809671
# Model saved! (time elapsed: 36.79845595359802)
# [ Train epoch: 1 ]
# Train accuarcy: 56.12387172525134
# Train average loss: 0.03520176542682694
# [ Validation epoch: 2 ]
# Accuarcy: 63.66304666862342
# Average loss: 0.03038395962688557
# Model saved! (time elapsed: 73.26515674591064)
# [ Train epoch: 2 ]
# Train accuarcy: 58.58222646217069
# Train average loss: 0.033470766533144576
# [ Validation epoch: 3 ]
# Accuarcy: 68.09509832697388
# Average loss: 0.027867396013597466
# Model saved! (time elapsed: 109.50148606300354)
# [ Train epoch: 3 ]
# Train accuarcy: 60.04256255962427
# Train average loss: 0.032676968587121075
# [ Validation epoch: 4 ]
# Accuarcy: 71.49985324332258
# Average loss: 0.025300889166352473
# Model saved! (time elapsed: 145.79992604255676)
# [ Train epoch: 4 ]
# Train accuarcy: 62.21472077493212
# Train average loss: 0.030980678518668585
# [ Validation epoch: 5 ]
# Accuarcy: 69.88552979160552
# Average loss: 0.026228198416953147
# Model saved! (time elapsed: 181.98904538154602)
# [ Train epoch: 5 ]
# Train accuarcy: 62.87517428634329
# Train average loss: 0.030692849644231038
# [ Validation epoch: 6 ]
# Accuarcy: 68.97563839154681
# Average loss: 0.026300744608696303
# Model saved! (time elapsed: 218.169579744339)
# [ Train epoch: 6 ]
# Train accuarcy: 63.36684523372716
# Train average loss: 0.030219497702184194
# [ Validation epoch: 7 ]
# Accuarcy: 71.76401526269446
# Average loss: 0.024635925945873164
# Model saved! (time elapsed: 254.57819843292236)
# [ Train epoch: 7 ]
# Train accuarcy: 63.799809202318926
# Train average loss: 0.029721988299854032
# [ Validation epoch: 8 ]
# Accuarcy: 74.7872028177282
# Average loss: 0.02235452931823708
# Model saved! (time elapsed: 290.8587703704834)
# [ Train epoch: 8 ]
# Train accuarcy: 64.73178249064358
# Train average loss: 0.028859972988788472
# [ Validation epoch: 9 ]
# Accuarcy: 71.0595832110361
# Average loss: 0.025235557830820064
# Model saved! (time elapsed: 329.8776664733887)
# [ Train epoch: 9 ]
# Train accuarcy: 65.34820576796066
# Train average loss: 0.028569183346460088
# [ Validation epoch: 10 ]
# Accuarcy: 72.99677135309656
# Average loss: 0.023784091623430557
# Model saved! (time elapsed: 367.6869156360626)
# [ Train epoch: 10 ]
# Train accuarcy: 66.12607323695605
# Train average loss: 0.028261090257490268
# [ Validation epoch: 11 ]
# Accuarcy: 75.60904021132961
# Average loss: 0.02229176901252451
# Model saved! (time elapsed: 404.025141954422)
# [ Train epoch: 11 ]
# Train accuarcy: 66.42694650326557
# Train average loss: 0.02785021284053985
# [ Validation epoch: 12 ]
# Accuarcy: 75.1981215145289
# Average loss: 0.02220218557572484
# Model saved! (time elapsed: 440.2461154460907)
# [ Train epoch: 12 ]
# Train accuarcy: 67.16812211051588
# Train average loss: 0.027672840057469485
# [ Validation epoch: 13 ]
# Accuarcy: 75.90255356618727
# Average loss: 0.021957311649143364
# Model saved! (time elapsed: 476.55718088150024)
# [ Train epoch: 13 ]
# Train accuarcy: 67.32956630219417
# Train average loss: 0.02728100490734531
# [ Validation epoch: 14 ]
# Accuarcy: 71.0595832110361
# Average loss: 0.02595926567120464
# Model saved! (time elapsed: 512.9030239582062)
# [ Train epoch: 14 ]
# Train accuarcy: 67.5717325897116
# Train average loss: 0.02691374324060391
# [ Validation epoch: 15 ]
# Accuarcy: 75.46228353390079
# Average loss: 0.02149856614513694
# Model saved! (time elapsed: 549.1418800354004)
# [ Train epoch: 15 ]
# Train accuarcy: 68.27621633521684
# Train average loss: 0.026726183917890372
# [ Validation epoch: 16 ]
# Accuarcy: 75.66774288230114
# Average loss: 0.021860251966934943
# Model saved! (time elapsed: 585.3119885921478)
# [ Train epoch: 16 ]
# Train accuarcy: 67.43230351508035
# Train average loss: 0.02720076889138653
# [ Validation epoch: 17 ]
# Accuarcy: 73.70120340475492
# Average loss: 0.022789528363255557
# Model saved! (time elapsed: 622.368175983429)
# [ Train epoch: 17 ]
# Train accuarcy: 68.43032215454612
# Train average loss: 0.026411285616116838
# [ Validation epoch: 18 ]
# Accuarcy: 75.25682418550043
# Average loss: 0.023144188910801458
# Model saved! (time elapsed: 660.2906301021576)
# [ Train epoch: 18 ]
# Train accuarcy: 68.32024656931092
# Train average loss: 0.026536942103502728
# [ Validation epoch: 19 ]
# Accuarcy: 75.2861755209862
# Average loss: 0.021481805107339512
# Model saved! (time elapsed: 698.8145923614502)
# [ Train epoch: 19 ]
# Train accuarcy: 69.50906288985104
# Train average loss: 0.025946697203667032
# [ Validation epoch: 20 ]
# Accuarcy: 72.9674200176108
# Average loss: 0.02320854668922357
# Model saved! (time elapsed: 736.3878226280212)
# [ Train epoch: 20 ]
# Train accuarcy: 69.4356791663609
# Train average loss: 0.025761967459139282
# [ Validation epoch: 21 ]
# Accuarcy: 76.3721749339595
# Average loss: 0.021257478198173776
# Model saved! (time elapsed: 775.0652203559875)
# [ Train epoch: 21 ]
# Train accuarcy: 69.73655243267044
# Train average loss: 0.02545849004066147
# [ Validation epoch: 22 ]
# Accuarcy: 76.90049897270326
# Average loss: 0.021242678541573114
# Model saved! (time elapsed: 813.0916826725006)
# [ Train epoch: 22 ]
# Train accuarcy: 69.9933954648859
# Train average loss: 0.02573210563708307
# [ Validation epoch: 23 ]
# Accuarcy: 78.28001174053419
# Average loss: 0.01981491847649886
# Model saved! (time elapsed: 851.1689255237579)
# [ Train epoch: 23 ]
# Train accuarcy: 69.97138034783885
# Train average loss: 0.0251383216770185
# [ Validation epoch: 24 ]
# Accuarcy: 76.3721749339595
# Average loss: 0.021247875149872145
# Model saved! (time elapsed: 890.5232925415039)
# [ Train epoch: 24 ]
# Train accuarcy: 70.03008732663095
# Train average loss: 0.025253230386691177
# [ Validation epoch: 25 ]
# Accuarcy: 76.66568828881714
# Average loss: 0.021120933128620893
# Model saved! (time elapsed: 929.2217619419098)
# [ Train epoch: 25 ]
# Train accuarcy: 70.18419314596022
# Train average loss: 0.02516257157545845
# [ Validation epoch: 26 ]
# Accuarcy: 74.66979747578515
# Average loss: 0.022087028842186485
# Model saved! (time elapsed: 966.7152047157288)
# [ Train epoch: 26 ]
# Train accuarcy: 70.23556175240331
# Train average loss: 0.024918011100099575
# [ Validation epoch: 27 ]
# Accuarcy: 75.60904021132961
# Average loss: 0.02221961474275183
# Model saved! (time elapsed: 1004.8703479766846)
# [ Train epoch: 27 ]
# Train accuarcy: 71.02810596609672
# Train average loss: 0.02456241858331825
# [ Validation epoch: 28 ]
# Accuarcy: 75.49163486938656
# Average loss: 0.02181413251002373
# Model saved! (time elapsed: 1042.6827504634857)
# [ Train epoch: 28 ]
# Train accuarcy: 71.11616643428488
# Train average loss: 0.02460847785277439
# [ Validation epoch: 29 ]
# Accuarcy: 77.22336366304667
# Average loss: 0.021627064994398294
# Model saved! (time elapsed: 1082.2239527702332)
# [ Train epoch: 29 ]
# Train accuarcy: 71.2996257430102
# Train average loss: 0.02447276726423045
# [ Validation epoch: 30 ]
# Accuarcy: 78.51482242442032
# Average loss: 0.020621190554486156
# Model saved! (time elapsed: 1119.853259086609)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = CustomLeNet()
net = net.to(device)

file_name = "./checkpoint/CustomLeNet.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.7266, 0.9500, 0.7828, 0.7846, 0.7125, 0.7580])
# [ 전체 평균 정확도 ]
# tensor(0.7851)

# %% [markdown]
# #### <b>Problem 4. AlexNet 아키텍처 작성하기</b>
#
# * AlexNet은 CNN 기반의 분류 모델의 우수성을 전 세계에 알린 논문([NIPS 2012](https://papers.nips.cc/paper/2012/file/c399862d3b9d6b76c8436e924a68c45b-Paper.pdf))입니다.
#     * ImageNet 분류 대회(ILSVRC 2012)에서 압도적인 성능으로 우승(1위)을 차지했습니다.
#
# <hr>
#
# * LRN (Local Response Normalization)을 활용합니다.
#     * PyTorch에서 [nn.LocalResponseNorm()](https://pytorch.org/docs/stable/generated/torch.nn.LocalResponseNorm.html)을 이용해 구현할 수 있습니다.
#     * Local Response Normalization은 입력과 출력의 차원이 동일한 레이어입니다.
# * Dropout을 활용합니다.
#     * PyTorch에서 [nn.Dropout()](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html)을 이용해 구현할 수 있습니다.
# * ReLU를 적극적으로 활용합니다.
#     * PyTorch에서 [nn.ReLU()](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html)를 이용해 구현할 수 있습니다.
#
# <hr>
#
# * <b>아래의 표</b>와 같은 아키텍처를 PyTorch로 구현해 봅시다.
#     * 원본 논문에서 제안한 것과 완전히 동일한 아키텍처는 아니지만, 핵심 아이디어를 잘 포함하고 있습니다.
#
# Layer | Type | Specification
# :-: | :-: | ---
# 1 | Input | image size: 3 X 64 X 64
# 2 | Convolution | # of kernel: 96, kernel size: 5 X 5, stride: 1, zero padding: 2
# 3 | Activation | ReLU
# 4 | Normalization | LRN (Local Response Normalization), size: 5
# 5 | Pooling | max pooling, kernel size: 3 X 3, stride: 2
# 6 | Convolution | # of kernel: 256, kernel size: 5 X 5, stride: 1, zero padding: 2
# 7 | Activation | ReLU
# 8 | Normalization | LRN (Local Response Normalization), size: 5
# 9 | Pooling | max pooling, kernel size: 3 X 3, stride: 2
# 10 | Convolution | # of kernel: 384, kernel size: 3 X 3, stride: 1, zero padding: 1
# 11 | Activation | ReLU
# 12 | Convolution | # of kernel: 384, kernel size: 3 X 3, stride: 1, zero padding: 1
# 13 | Activation | ReLU
# 14 | Convolution | # of kernel: 256, kernel size: 3 X 3, stride: 1, zero padding: 1
# 15 | Activation | ReLU
# 16 | Pooling | max pooling, kernel size: 3 X 3, stride: 2
# 17 | Fully Connected | # of neuron: 4096
# 18 | Activation | ReLU
# 19 | Dropout | Probability: 0.5
# 20 | Fully Connected | # of neuron: 6
# 21 | Dropout | Probability: 0.5
# 22 | Softmax | 6 classes
#
# * 표와 동일하게 정상적으로 구현했다면, <b>83~85%가량의 정확도</b>를 얻을 수 있습니다.

# %%
class AlexNet(nn.Module):
    def __init__(self):
        super(AlexNet, self).__init__()
        # 이 부분에 소스코드를 작성하세요.
        self.features=nn.Sequential(
            nn.Conv2d(3,96,kernel_size=5,stride=1,padding=2),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(size=5),
            nn.MaxPool2d(kernel_size=3,stride=2),

            nn.Conv2d(96,256,kernel_size=5,stride=1,padding=2),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(size=5),
            nn.MaxPool2d(kernel_size=3,stride=2),

            nn.Conv2d(256,384,kernel_size=3,stride=1,padding=1),
            nn.ReLU(inplace=True),

            nn.Conv2d(384,384,kernel_size=3,stride=1,padding=1),
            nn.ReLU(inplace=True),

            nn.Conv2d(384,384,kernel_size=3,stride=1,padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3,stride=2),

        )

        self.classifier=nn.Sequential(
        nn.Linear(18816,4096),
        nn.ReLU(inplace=True),
        nn.Dropout(),
        nn.Linear(4096,6),
        nn.Dropout(),
        )

    def forward(self, x):
        # 이 부분에 소스코드를 작성하세요.
        x=self.features(x)
        x=torch.flatten(x,1)
        x=self.classifier(x)
        return x

# %% [markdown]
# #### <b>(알아보기) AlexNet 평가하기</b>
#
# * 아래 코드를 실행하여 학습 및 성능 평가를 진행할 수 있습니다.
# * 83~85%가량의 정확도가 나오지 않는다면, 표와 동일하게 AlexNet 코드를 다시 작성했는지 확인해 주세요.

# %%
import time
import torch.optim as optim


net = AlexNet()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "AlexNet.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 30.608351067733178
# Train average loss: 0.050823688043434935
# [ Validation epoch: 1 ]
# Accuarcy: 55.67948341649545
# Average loss: 0.039207005399323855
# Model saved! (time elapsed: 45.73633146286011)
# [ Train epoch: 1 ]
# Train accuarcy: 39.13553973728627
# Train average loss: 0.04558286026864861
# [ Validation epoch: 2 ]
# Accuarcy: 62.95861461696507
# Average loss: 0.035455333616224806
# Model saved! (time elapsed: 91.41608333587646)
# [ Train epoch: 2 ]
# Train accuarcy: 40.61055257943788
# Train average loss: 0.04427479091495081
# [ Validation epoch: 3 ]
# Accuarcy: 61.13883181684767
# Average loss: 0.034276488644656176
# Model saved! (time elapsed: 136.80006790161133)
# [ Train epoch: 3 ]
# Train accuarcy: 42.834079401188816
# Train average loss: 0.04246976475832161
# [ Validation epoch: 4 ]
# Accuarcy: 68.828881714118
# Average loss: 0.029248916826396524
# Model saved! (time elapsed: 182.12890315055847)
# [ Train epoch: 4 ]
# Train accuarcy: 44.55125853085786
# Train average loss: 0.041326404702613555
# [ Validation epoch: 5 ]
# Accuarcy: 71.0595832110361
# Average loss: 0.02873971508086025
# Model saved! (time elapsed: 229.08160424232483)
# [ Train epoch: 5 ]
# Train accuarcy: 46.29045277757393
# Train average loss: 0.03995181534937142
# [ Validation epoch: 6 ]
# Accuarcy: 75.16877017904315
# Average loss: 0.02433515911512372
# Model saved! (time elapsed: 277.5935802459717)
# [ Train epoch: 6 ]
# Train accuarcy: 47.17839583180451
# Train average loss: 0.039359163921297693
# [ Validation epoch: 7 ]
# Accuarcy: 77.45817434693278
# Average loss: 0.023717004303922394
# Model saved! (time elapsed: 325.43297266960144)
# [ Train epoch: 7 ]
# Train accuarcy: 47.86086446026271
# Train average loss: 0.038539633503696435
# [ Validation epoch: 8 ]
# Accuarcy: 73.08482535955386
# Average loss: 0.025771480013206623
# Model saved! (time elapsed: 373.31507778167725)
# [ Train epoch: 8 ]
# Train accuarcy: 48.77816100388934
# Train average loss: 0.037791936043432575
# [ Validation epoch: 9 ]
# Accuarcy: 75.13941884355738
# Average loss: 0.023261335253330632
# Model saved! (time elapsed: 419.2041893005371)
# [ Train epoch: 9 ]
# Train accuarcy: 48.80017612093638
# Train average loss: 0.03745415037600531
# [ Validation epoch: 10 ]
# Accuarcy: 79.65952450836512
# Average loss: 0.02085519765946814
# Model saved! (time elapsed: 466.1938214302063)
# [ Train epoch: 10 ]
# Train accuarcy: 49.51933661113965
# Train average loss: 0.03721428910818315
# [ Validation epoch: 11 ]
# Accuarcy: 77.83974170824773
# Average loss: 0.02109215163855669
# Model saved! (time elapsed: 515.1987907886505)
# [ Train epoch: 11 ]
# Train accuarcy: 50.01100755852352
# Train average loss: 0.03659820047943172
# [ Validation epoch: 12 ]
# Accuarcy: 79.07249779864983
# Average loss: 0.02252544757030141
# Model saved! (time elapsed: 561.0265581607819)
# [ Train epoch: 12 ]
# Train accuarcy: 50.83290526161297
# Train average loss: 0.03601239286918077
# [ Validation epoch: 13 ]
# Accuarcy: 81.62606398591136
# Average loss: 0.017730614325151366
# Model saved! (time elapsed: 606.4228439331055)
# [ Train epoch: 13 ]
# Train accuarcy: 51.15579364496955
# Train average loss: 0.03553650222503842
# [ Validation epoch: 14 ]
# Accuarcy: 81.12709128265337
# Average loss: 0.018913667512352877
# Model saved! (time elapsed: 651.4843573570251)
# [ Train epoch: 14 ]
# Train accuarcy: 51.273207602553754
# Train average loss: 0.035515629970520865
# [ Validation epoch: 15 ]
# Accuarcy: 80.86292926328147
# Average loss: 0.018853312386142428
# Model saved! (time elapsed: 696.6257166862488)
# [ Train epoch: 15 ]
# Train accuarcy: 51.309899464298816
# Train average loss: 0.03532854078835504
# [ Validation epoch: 16 ]
# Accuarcy: 81.03903727619607
# Average loss: 0.01812053884898668
# Model saved! (time elapsed: 741.989509344101)
# [ Train epoch: 16 ]
# Train accuarcy: 51.85293901812578
# Train average loss: 0.034821441209945236
# [ Validation epoch: 17 ]
# Accuarcy: 82.71206339888465
# Average loss: 0.017756559455503213
# Model saved! (time elapsed: 787.0278692245483)
# [ Train epoch: 17 ]
# Train accuarcy: 51.69883319879651
# Train average loss: 0.03469309919148327
# [ Validation epoch: 18 ]
# Accuarcy: 81.83152333431171
# Average loss: 0.017164569591930055
# Model saved! (time elapsed: 832.2003343105316)
# [ Train epoch: 18 ]
# Train accuarcy: 52.19050414618038
# Train average loss: 0.03416446295944184
# [ Validation epoch: 19 ]
# Accuarcy: 82.62400939242735
# Average loss: 0.016814834610751762
# Model saved! (time elapsed: 877.2409789562225)
# [ Train epoch: 19 ]
# Train accuarcy: 52.34460996550965
# Train average loss: 0.034021603734825503
# [ Validation epoch: 20 ]
# Accuarcy: 82.94687408277076
# Average loss: 0.017855041794039336
# Model saved! (time elapsed: 924.1302902698517)
# [ Train epoch: 20 ]
# Train accuarcy: 52.63814485947017
# Train average loss: 0.0338284815845796
# [ Validation epoch: 21 ]
# Accuarcy: 81.53800997945406
# Average loss: 0.017930480586772164
# Model saved! (time elapsed: 970.5538783073425)
# [ Train epoch: 21 ]
# Train accuarcy: 52.84361928524253
# Train average loss: 0.03369109691121026
# [ Validation epoch: 22 ]
# Accuarcy: 83.32844144408571
# Average loss: 0.01588098537302591
# Model saved! (time elapsed: 1016.5992949008942)
# [ Train epoch: 22 ]
# Train accuarcy: 53.357305349673446
# Train average loss: 0.033382178087739085
# [ Validation epoch: 23 ]
# Accuarcy: 83.76871147637218
# Average loss: 0.01587656292531859
# Model saved! (time elapsed: 1061.778734922409)
# [ Train epoch: 23 ]
# Train accuarcy: 53.41601232846555
# Train average loss: 0.0331876160962536
# [ Validation epoch: 24 ]
# Accuarcy: 82.8294687408277
# Average loss: 0.01593531335348393
# Model saved! (time elapsed: 1107.0862970352173)
# [ Train epoch: 24 ]
# Train accuarcy: 53.37198209437147
# Train average loss: 0.03343205327918387
# [ Validation epoch: 25 ]
# Accuarcy: 82.27179336659817
# Average loss: 0.0172774929663706
# Model saved! (time elapsed: 1152.3230473995209)
# [ Train epoch: 25 ]
# Train accuarcy: 53.680193733030016
# Train average loss: 0.033180285254201525
# [ Validation epoch: 26 ]
# Accuarcy: 84.17963017317288
# Average loss: 0.015376130970195483
# Model saved! (time elapsed: 1197.5658702850342)
# [ Train epoch: 26 ]
# Train accuarcy: 53.335290232626406
# Train average loss: 0.03296376515565059
# [ Validation epoch: 27 ]
# Accuarcy: 84.59054886997359
# Average loss: 0.015905571991584853
# Model saved! (time elapsed: 1243.5545494556427)
# [ Train epoch: 27 ]
# Train accuarcy: 53.8416379247083
# Train average loss: 0.03283990978748492
# [ Validation epoch: 28 ]
# Accuarcy: 83.71000880540065
# Average loss: 0.017178797664130087
# Model saved! (time elapsed: 1288.9417042732239)
# [ Train epoch: 28 ]
# Train accuarcy: 54.21589491450796
# Train average loss: 0.03272792995479055
# [ Validation epoch: 29 ]
# Accuarcy: 85.17757557968888
# Average loss: 0.01459840223923575
# Model saved! (time elapsed: 1334.0520601272583)
# [ Train epoch: 29 ]
# Train accuarcy: 54.31129375504513
# Train average loss: 0.03213675060441579
# [ Validation epoch: 30 ]
# Accuarcy: 83.09363076019959
# Average loss: 0.015357103381368259
# Model saved! (time elapsed: 1378.9606540203094)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = AlexNet()
net = net.to(device)

file_name = "./checkpoint/AlexNet.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.6597, 0.9204, 0.8872, 0.7078, 0.8536, 0.9475])
# [ 전체 평균 정확도 ]
# tensor(0.8309)

# %% [markdown]
# #### <b>(알아보기) LightResNet 아키텍처 살펴보기</b>
#
# * [ResNet (2016 CVPR)](https://arxiv.org/abs/1512.03385) 논문에서 제안된 가벼운 ResNet을 PyTorch로 구현한 것은 다음과 같습니다.
#     * 원본 논문에서는 CIFAR-10을 위하여 해당 아키텍처를 제안했습니다.
# * 레이어의 깊이에 따라 다양한 버전이 있습니다.
#     * 다양한 버전: 20 레이어, 32 레이어, 44 레이어, 56 레이어, 110 레이어
#     * 일반적으로 더 깊은 레이어로 구성된 ResNet이 더 높은 정확도를 보입니다.

# %%
# ResNet을 위한 BasicBlock 클래스 정의
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (stride 값이 2라면, 너비와 높이가 절반으로 감소)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (stride 값이 1이므로, 너비와 높이가 유지)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, padding=0, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out


# LightResNet 클래스 정의
class LightResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=6):
        super(LightResNet, self).__init__()
        self.in_planes = 16

        # 16개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        # 첫 레이어를 제외하고는 너비와 높이를 줄이기 위해 stride를 2로 설정
        self.layer1 = self._make_layer(block, 16, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 32, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 64, num_blocks[2], stride=2)
        self.linear = nn.Linear(64, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1) # 첫째 블록만 너비와 높이 감소
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1) # 배치(batch)를 제외한 모든 차원 flatten하기
        out = self.linear(out)
        return out


def LightResNet20():
    return LightResNet(BasicBlock, [3, 3, 3])


def LightResNet32():
    return LightResNet(BasicBlock, [5, 5, 5])


def LightResNet44():
    return LightResNet(BasicBlock, [7, 7, 7])


def LightResNet56():
    return LightResNet(BasicBlock, [9, 9, 9])


def LightResNet110():
    return LightResNet(BasicBlock, [18, 18, 18])

# %% [markdown]
# #### <b>(알아보기) LightResNet-20 학습하기</b>
#
# * PyTorch로 구현된 LightResNet-20 모델을 학습해 봅시다.

# %%
import time
import torch.optim as optim


net = LightResNet20()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "LightResNet20.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 52.7115285829603
# Train average loss: 0.03643683930297866
# [ Validation epoch: 1 ]
# Accuarcy: 68.94628705606105
# Average loss: 0.02615179944185347
# Model saved! (time elapsed: 19.377859115600586)
# [ Train epoch: 1 ]
# Train accuarcy: 65.37755925735672
# Train average loss: 0.02823991254393052
# [ Validation epoch: 2 ]
# Accuarcy: 74.20017610801291
# Average loss: 0.022833672373183563
# Model saved! (time elapsed: 37.45249271392822)
# [ Train epoch: 2 ]
# Train accuarcy: 70.25023849710135
# Train average loss: 0.025199565274564784
# [ Validation epoch: 3 ]
# Accuarcy: 77.86909304373349
# Average loss: 0.019884931645786655
# Model saved! (time elapsed: 55.6118106842041)
# [ Train epoch: 3 ]
# Train accuarcy: 72.40771996771116
# Train average loss: 0.023608929455967025
# [ Validation epoch: 4 ]
# Accuarcy: 73.58379806281185
# Average loss: 0.022376652219829443
# Model saved! (time elapsed: 74.05759286880493)
# [ Train epoch: 4 ]
# Train accuarcy: 73.3837234901299
# Train average loss: 0.02222287116435983
# [ Validation epoch: 5 ]
# Accuarcy: 77.48752568241855
# Average loss: 0.01932468852900255
# Model saved! (time elapsed: 92.59714984893799)
# [ Train epoch: 5 ]
# Train accuarcy: 74.84405958758347
# Train average loss: 0.02134715936902492
# [ Validation epoch: 6 ]
# Accuarcy: 77.04725565013209
# Average loss: 0.018846285502372474
# Model saved! (time elapsed: 110.80106806755066)
# [ Train epoch: 6 ]
# Train accuarcy: 75.78337124825714
# Train average loss: 0.02082700441385248
# [ Validation epoch: 7 ]
# Accuarcy: 79.21925447607866
# Average loss: 0.01879485944761081
# Model saved! (time elapsed: 128.95330333709717)
# [ Train epoch: 7 ]
# Train accuarcy: 75.57055845013576
# Train average loss: 0.02033881182723781
# [ Validation epoch: 8 ]
# Accuarcy: 78.25066040504844
# Average loss: 0.018489786662382223
# Model saved! (time elapsed: 147.156014919281)
# [ Train epoch: 8 ]
# Train accuarcy: 77.01621780289132
# Train average loss: 0.01957090739621414
# [ Validation epoch: 9 ]
# Accuarcy: 83.416495450543
# Average loss: 0.015231081440121958
# Model saved! (time elapsed: 165.2987620830536)
# [ Train epoch: 9 ]
# Train accuarcy: 77.5739341014163
# Train average loss: 0.019001590299739295
# [ Validation epoch: 10 ]
# Accuarcy: 82.85882007631348
# Average loss: 0.015023322706527642
# Model saved! (time elapsed: 183.5359754562378)
# [ Train epoch: 10 ]
# Train accuarcy: 77.77207015483965
# Train average loss: 0.01891179983462085
# [ Validation epoch: 11 ]
# Accuarcy: 81.74346932785441
# Average loss: 0.015702002649262463
# Model saved! (time elapsed: 203.40896701812744)
# [ Train epoch: 11 ]
# Train accuarcy: 78.11697365524327
# Train average loss: 0.01877742888529075
# [ Validation epoch: 12 ]
# Accuarcy: 81.89022600528324
# Average loss: 0.015901241448221578
# Model saved! (time elapsed: 221.682612657547)
# [ Train epoch: 12 ]
# Train accuarcy: 78.42518529390182
# Train average loss: 0.018070736475829605
# [ Validation epoch: 13 ]
# Accuarcy: 84.88406222483123
# Average loss: 0.014074137589082642
# Model saved! (time elapsed: 240.21274995803833)
# [ Train epoch: 13 ]
# Train accuarcy: 79.28377485873634
# Train average loss: 0.017755419943174682
# [ Validation epoch: 14 ]
# Accuarcy: 82.44790137951277
# Average loss: 0.015286487180850078
# Model saved! (time elapsed: 258.3421096801758)
# [ Train epoch: 14 ]
# Train accuarcy: 79.29845160343436
# Train average loss: 0.017703243397674356
# [ Validation epoch: 15 ]
# Accuarcy: 83.71000880540065
# Average loss: 0.014127664803793818
# Model saved! (time elapsed: 276.5800039768219)
# [ Train epoch: 15 ]
# Train accuarcy: 79.10765392236002
# Train average loss: 0.017669077365311103
# [ Validation epoch: 16 ]
# Accuarcy: 82.97622541825653
# Average loss: 0.014911537051270846
# Model saved! (time elapsed: 297.8107330799103)
# [ Train epoch: 16 ]
# Train accuarcy: 79.67270859323402
# Train average loss: 0.0171753487255775
# [ Validation epoch: 17 ]
# Accuarcy: 84.56119753448782
# Average loss: 0.014499951015128954
# Model saved! (time elapsed: 315.96041798591614)
# [ Train epoch: 17 ]
# Train accuarcy: 79.95156674249651
# Train average loss: 0.017064184556224687
# [ Validation epoch: 18 ]
# Accuarcy: 78.74963310830643
# Average loss: 0.018080072110616675
# Model saved! (time elapsed: 333.98343801498413)
# [ Train epoch: 18 ]
# Train accuarcy: 80.19373303001395
# Train average loss: 0.01685794802818486
# [ Validation epoch: 19 ]
# Accuarcy: 82.09568535368359
# Average loss: 0.015190094359501177
# Model saved! (time elapsed: 354.40017318725586)
# [ Train epoch: 19 ]
# Train accuarcy: 80.72943421149189
# Train average loss: 0.01651591505086316
# [ Validation epoch: 20 ]
# Accuarcy: 83.76871147637218
# Average loss: 0.014469321208123347
# Model saved! (time elapsed: 383.17401242256165)
# [ Train epoch: 20 ]
# Train accuarcy: 80.72209583914288
# Train average loss: 0.016432968795041462
# [ Validation epoch: 21 ]
# Accuarcy: 81.89022600528324
# Average loss: 0.0163744301880984
# Model saved! (time elapsed: 408.509890794754)
# [ Train epoch: 21 ]
# Train accuarcy: 80.81015630733103
# Train average loss: 0.016408662768201798
# [ Validation epoch: 22 ]
# Accuarcy: 84.94276489580275
# Average loss: 0.012676759439022757
# Model saved! (time elapsed: 435.6213548183441)
# [ Train epoch: 22 ]
# Train accuarcy: 81.51464005283628
# Train average loss: 0.01594931850488812
# [ Validation epoch: 23 ]
# Accuarcy: 86.05811564426182
# Average loss: 0.012503799636027385
# Model saved! (time elapsed: 454.05834555625916)
# [ Train epoch: 23 ]
# Train accuarcy: 81.22844353122477
# Train average loss: 0.0159998415365357
# [ Validation epoch: 24 ]
# Accuarcy: 84.8253595538597
# Average loss: 0.013255849992350676
# Model saved! (time elapsed: 472.55353450775146)
# [ Train epoch: 24 ]
# Train accuarcy: 81.37521097820503
# Train average loss: 0.015967970383598543
# [ Validation epoch: 25 ]
# Accuarcy: 83.68065746991488
# Average loss: 0.014022548798070402
# Model saved! (time elapsed: 490.6072359085083)
# [ Train epoch: 25 ]
# Train accuarcy: 81.4632714463932
# Train average loss: 0.015738796012727183
# [ Validation epoch: 26 ]
# Accuarcy: 85.3243322571177
# Average loss: 0.013535634584184752
# Model saved! (time elapsed: 508.58710861206055)
# [ Train epoch: 26 ]
# Train accuarcy: 81.77148308505174
# Train average loss: 0.01541288812791924
# [ Validation epoch: 27 ]
# Accuarcy: 83.26973877311417
# Average loss: 0.01442159588101815
# Model saved! (time elapsed: 526.8171589374542)
# [ Train epoch: 27 ]
# Train accuarcy: 81.70543773391061
# Train average loss: 0.015422618674752543
# [ Validation epoch: 28 ]
# Accuarcy: 82.44790137951277
# Average loss: 0.014621331513645294
# Model saved! (time elapsed: 545.3032808303833)
# [ Train epoch: 28 ]
# Train accuarcy: 81.33118074411095
# Train average loss: 0.015596412950577893
# [ Validation epoch: 29 ]
# Accuarcy: 85.0014675667743
# Average loss: 0.01339684766182845
# Model saved! (time elapsed: 564.8379774093628)
# [ Train epoch: 29 ]
# Train accuarcy: 82.63741102223527
# Train average loss: 0.015050725653410011
# [ Validation epoch: 30 ]
# Accuarcy: 85.79395362488994
# Average loss: 0.012737117364394689
# Model saved! (time elapsed: 582.820077419281)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = LightResNet20()
net = net.to(device)

file_name = "./checkpoint/LightResNet20.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.6482, 0.9759, 0.8232, 0.8397, 0.9054, 0.9442])
# [ 전체 평균 정확도 ]
# tensor(0.8579)

# %% [markdown]
# #### <b>Problem 5. 다양한 레이어 깊이에 따라 LightResNet 학습하기</b>
#
# * Residual Block을 사용하는 경우 깊이가 깊어져도 좋은 성능을 내는 경향이 있습니다.
# * 다음의 LightResNet 모델들에 대하여 각각 학습을 진행한 뒤에, 검증 정확도(validation accuracy)를 쓰세요.
#     * LightResNet32: 87.026709
#     * LightResNet56: 85.500402
#     * LightResNet110: 82.271793
# * 레이어가 깊어짐에 따라서 성능이 좋아지나요?  꼭 그렇다고 단정지을 수 없다.
#     * 그 이유는: 과적합 될 가능성도 높아지기 때문에

# %%
def lightresnettrain(net,name):

    net = net.to(device)

    epoch = 30
    learning_rate = 0.002
    file_name = name+".pt"

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

    train_result = []
    val_result = []

    # acc_list=[]
    start_time = time.time() # 시작 시간

    for i in range(epoch):
        train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
        val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

        # 학습된 모델 저장하기
        state = {
            'net': net.state_dict()
        }
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        torch.save(state, './checkpoint/' + file_name)
        print(f'Model saved! (time elapsed: {time.time() - start_time})')

        
        # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
        train_result.append((train_acc, train_loss))
        val_result.append((val_acc, val_loss))

# %%
net=LightResNet32()
lightresnettrain(net,"LightResNet32")
net=LightResNet56()
lightresnettrain(net,"LightResNet56")
net=LightResNet110()
lightresnettrain(net,"LightResNet110")
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 52.44000880604682
# Train average loss: 0.03675420800229551
# [ Validation epoch: 1 ]
# Accuarcy: 67.830936307602
# Average loss: 0.027544199510652158
# Model saved! (time elapsed: 23.543094158172607)
# [ Train epoch: 1 ]
# Train accuarcy: 65.54634182138402
# Train average loss: 0.02865199556072171
# [ Validation epoch: 2 ]
# Accuarcy: 61.81391253302025
# Average loss: 0.03023744461331369
# Model saved! (time elapsed: 47.04926037788391)
# [ Train epoch: 2 ]
# Train accuarcy: 69.36963381521979
# Train average loss: 0.025502753172895656
# [ Validation epoch: 3 ]
# Accuarcy: 70.20839448194893
# Average loss: 0.02486764099684005
# Model saved! (time elapsed: 70.54466366767883)
# [ Train epoch: 3 ]
# Train accuarcy: 71.27027225361415
# Train average loss: 0.024124090937654122
# [ Validation epoch: 4 ]
# Accuarcy: 77.51687701790432
# Average loss: 0.019247973729761458
# Model saved! (time elapsed: 94.197838306427)
# [ Train epoch: 4 ]
# Train accuarcy: 73.6112130329493
# Train average loss: 0.022231925550364098
# [ Validation epoch: 5 ]
# Accuarcy: 80.83357792779572
# Average loss: 0.01713122435773542
# Model saved! (time elapsed: 118.81578803062439)
# [ Train epoch: 5 ]
# Train accuarcy: 74.44044910838775
# Train average loss: 0.0216113359464311
# [ Validation epoch: 6 ]
# Accuarcy: 76.48958027590255
# Average loss: 0.02043472811697794
# Model saved! (time elapsed: 142.55944180488586)
# [ Train epoch: 6 ]
# Train accuarcy: 75.32839216261833
# Train average loss: 0.02072014476536147
# [ Validation epoch: 7 ]
# Accuarcy: 81.74346932785441
# Average loss: 0.016140853371093937
# Model saved! (time elapsed: 166.264967918396)
# [ Train epoch: 7 ]
# Train accuarcy: 76.01819916342555
# Train average loss: 0.020375239345641935
# [ Validation epoch: 8 ]
# Accuarcy: 78.89638978573525
# Average loss: 0.018177594669165412
# Model saved! (time elapsed: 189.8489112854004)
# [ Train epoch: 8 ]
# Train accuarcy: 76.65663755778968
# Train average loss: 0.01969712736225709
# [ Validation epoch: 9 ]
# Accuarcy: 80.68682125036689
# Average loss: 0.01625270073036662
# Model saved! (time elapsed: 213.5980188846588)
# [ Train epoch: 9 ]
# Train accuarcy: 77.41248990973801
# Train average loss: 0.01905992482145403
# [ Validation epoch: 10 ]
# Accuarcy: 82.5946580569416
# Average loss: 0.01591728538021091
# Model saved! (time elapsed: 237.52604246139526)
# [ Train epoch: 10 ]
# Train accuarcy: 77.81610038893373
# Train average loss: 0.018966774506982514
# [ Validation epoch: 11 ]
# Accuarcy: 81.83152333431171
# Average loss: 0.01549572168486119
# Model saved! (time elapsed: 261.371285200119)
# [ Train epoch: 11 ]
# Train accuarcy: 78.25640272987451
# Train average loss: 0.018314709167247072
# [ Validation epoch: 12 ]
# Accuarcy: 81.71411799236866
# Average loss: 0.01643040744324811
# Model saved! (time elapsed: 285.0064649581909)
# [ Train epoch: 12 ]
# Train accuarcy: 79.35715858222646
# Train average loss: 0.017912601446155373
# [ Validation epoch: 13 ]
# Accuarcy: 83.09363076019959
# Average loss: 0.014072155999252094
# Model saved! (time elapsed: 309.1407117843628)
# [ Train epoch: 13 ]
# Train accuarcy: 78.57929111323108
# Train average loss: 0.01809400442416052
# [ Validation epoch: 14 ]
# Accuarcy: 83.59260346345759
# Average loss: 0.014161509351538605
# Model saved! (time elapsed: 333.39184832572937)
# [ Train epoch: 14 ]
# Train accuarcy: 78.66001320907023
# Train average loss: 0.0179458626892401
# [ Validation epoch: 15 ]
# Accuarcy: 83.915468153801
# Average loss: 0.014068029427286953
# Model saved! (time elapsed: 357.0468361377716)
# [ Train epoch: 15 ]
# Train accuarcy: 79.87084464665737
# Train average loss: 0.017237615867888245
# [ Validation epoch: 16 ]
# Accuarcy: 85.17757557968888
# Average loss: 0.01344116844317764
# Model saved! (time elapsed: 380.8274745941162)
# [ Train epoch: 16 ]
# Train accuarcy: 79.73141557202612
# Train average loss: 0.017190316542321487
# [ Validation epoch: 17 ]
# Accuarcy: 81.5086586439683
# Average loss: 0.015448583599966153
# Model saved! (time elapsed: 404.4950885772705)
# [ Train epoch: 17 ]
# Train accuarcy: 79.98825860424158
# Train average loss: 0.0168178669871575
# [ Validation epoch: 18 ]
# Accuarcy: 85.58849427648958
# Average loss: 0.012182997500822976
# Model saved! (time elapsed: 428.05047154426575)
# [ Train epoch: 18 ]
# Train accuarcy: 80.75878770088794
# Train average loss: 0.016514924491607425
# [ Validation epoch: 19 ]
# Accuarcy: 85.52979160551806
# Average loss: 0.012694640755915802
# Model saved! (time elapsed: 451.7252881526947)
# [ Train epoch: 19 ]
# Train accuarcy: 80.40654582813532
# Train average loss: 0.016557078533803515
# [ Validation epoch: 20 ]
# Accuarcy: 83.88611681831523
# Average loss: 0.014065174118563476
# Model saved! (time elapsed: 475.2087185382843)
# [ Train epoch: 20 ]
# Train accuarcy: 81.00095398840537
# Train average loss: 0.0160604845692811
# [ Validation epoch: 21 ]
# Accuarcy: 84.50249486351629
# Average loss: 0.013617382643157728
# Model saved! (time elapsed: 499.2199149131775)
# [ Train epoch: 21 ]
# Train accuarcy: 81.0229691054524
# Train average loss: 0.016278227289135725
# [ Validation epoch: 22 ]
# Accuarcy: 83.59260346345759
# Average loss: 0.014987135728608488
# Model saved! (time elapsed: 523.2750813961029)
# [ Train epoch: 22 ]
# Train accuarcy: 80.92757026491525
# Train average loss: 0.01604476408697919
# [ Validation epoch: 23 ]
# Accuarcy: 83.88611681831523
# Average loss: 0.014408055374725214
# Model saved! (time elapsed: 546.8623945713043)
# [ Train epoch: 23 ]
# Train accuarcy: 80.98627724370735
# Train average loss: 0.016054599964365864
# [ Validation epoch: 24 ]
# Accuarcy: 87.1441150572351
# Average loss: 0.011628425286195478
# Model saved! (time elapsed: 570.4312489032745)
# [ Train epoch: 24 ]
# Train accuarcy: 81.42657958464812
# Train average loss: 0.015497782066220572
# [ Validation epoch: 25 ]
# Accuarcy: 87.40827707660698
# Average loss: 0.011694064619151385
# Model saved! (time elapsed: 594.2370731830597)
# [ Train epoch: 25 ]
# Train accuarcy: 81.97695751082409
# Train average loss: 0.015530400112114939
# [ Validation epoch: 26 ]
# Accuarcy: 85.44173759906076
# Average loss: 0.013139269251014468
# Model saved! (time elapsed: 617.7515609264374)
# [ Train epoch: 26 ]
# Train accuarcy: 81.38988772290305
# Train average loss: 0.015543878369332409
# [ Validation epoch: 27 ]
# Accuarcy: 87.20281772820664
# Average loss: 0.011810127649011239
# Model saved! (time elapsed: 641.3569161891937)
# [ Train epoch: 27 ]
# Train accuarcy: 82.27783077713363
# Train average loss: 0.01519842289370137
# [ Validation epoch: 28 ]
# Accuarcy: 86.1461696507191
# Average loss: 0.012890618772303075
# Model saved! (time elapsed: 665.0885317325592)
# [ Train epoch: 28 ]
# Train accuarcy: 82.24113891538856
# Train average loss: 0.015073001851660757
# [ Validation epoch: 29 ]
# Accuarcy: 85.08952157323158
# Average loss: 0.012921397219156989
# Model saved! (time elapsed: 689.6787512302399)
# [ Train epoch: 29 ]
# Train accuarcy: 81.83019006384384
# Train average loss: 0.015270789275867815
# [ Validation epoch: 30 ]
# Accuarcy: 87.02670971529204
# Average loss: 0.011746562157938269
# Model saved! (time elapsed: 713.7976846694946)
# [ Train epoch: 0 ]
# Train accuarcy: 49.51199823879064
# Train average loss: 0.03819852745470879
# [ Validation epoch: 1 ]
# Accuarcy: 64.33812738479601
# Average loss: 0.029537146414064543
# Model saved! (time elapsed: 38.67184662818909)
# [ Train epoch: 1 ]
# Train accuarcy: 61.02590445439201
# Train average loss: 0.03111085763915038
# [ Validation epoch: 2 ]
# Accuarcy: 69.79747578514822
# Average loss: 0.02536592877677434
# Model saved! (time elapsed: 77.23487257957458)
# [ Train epoch: 2 ]
# Train accuarcy: 66.98466280179056
# Train average loss: 0.027315333924097913
# [ Validation epoch: 3 ]
# Accuarcy: 70.35515115937775
# Average loss: 0.025439851797323335
# Model saved! (time elapsed: 115.7059121131897)
# [ Train epoch: 3 ]
# Train accuarcy: 69.75122917736846
# Train average loss: 0.024997265889848103
# [ Validation epoch: 4 ]
# Accuarcy: 74.49368946287056
# Average loss: 0.022882083258672234
# Model saved! (time elapsed: 154.23707747459412)
# [ Train epoch: 4 ]
# Train accuarcy: 71.62251412636677
# Train average loss: 0.023592796264972325
# [ Validation epoch: 5 ]
# Accuarcy: 77.22336366304667
# Average loss: 0.019424268261302346
# Model saved! (time elapsed: 192.89444947242737)
# [ Train epoch: 5 ]
# Train accuarcy: 72.37102810596609
# Train average loss: 0.023157117369327698
# [ Validation epoch: 6 ]
# Accuarcy: 75.05136483710008
# Average loss: 0.02123006232714842
# Model saved! (time elapsed: 231.33499217033386)
# [ Train epoch: 6 ]
# Train accuarcy: 74.14691421442724
# Train average loss: 0.02197212253757974
# [ Validation epoch: 7 ]
# Accuarcy: 78.28001174053419
# Average loss: 0.01851392870849271
# Model saved! (time elapsed: 269.8293902873993)
# [ Train epoch: 7 ]
# Train accuarcy: 75.40911425845748
# Train average loss: 0.021031081457782617
# [ Validation epoch: 8 ]
# Accuarcy: 80.98033460522454
# Average loss: 0.016490022471163115
# Model saved! (time elapsed: 308.29380893707275)
# [ Train epoch: 8 ]
# Train accuarcy: 75.61458868422984
# Train average loss: 0.020899077213509483
# [ Validation epoch: 9 ]
# Accuarcy: 78.48547108893455
# Average loss: 0.019102845761934825
# Model saved! (time elapsed: 346.78618717193604)
# [ Train epoch: 9 ]
# Train accuarcy: 76.64196081309166
# Train average loss: 0.019565598133366675
# [ Validation epoch: 10 ]
# Accuarcy: 80.36395656002348
# Average loss: 0.017670953329756423
# Model saved! (time elapsed: 385.7803955078125)
# [ Train epoch: 10 ]
# Train accuarcy: 76.86945035591106
# Train average loss: 0.019210765540814148
# [ Validation epoch: 11 ]
# Accuarcy: 83.97417082477253
# Average loss: 0.014726897099691995
# Model saved! (time elapsed: 424.1290946006775)
# [ Train epoch: 11 ]
# Train accuarcy: 77.75005503779262
# Train average loss: 0.018755892326793852
# [ Validation epoch: 12 ]
# Accuarcy: 81.06838861168183
# Average loss: 0.017084313971505755
# Model saved! (time elapsed: 462.210932970047)
# [ Train epoch: 12 ]
# Train accuarcy: 77.7940852718867
# Train average loss: 0.018786436412517624
# [ Validation epoch: 13 ]
# Accuarcy: 80.0997945406516
# Average loss: 0.01643833619935232
# Model saved! (time elapsed: 500.6070601940155)
# [ Train epoch: 13 ]
# Train accuarcy: 78.45453878329786
# Train average loss: 0.018197135452637365
# [ Validation epoch: 14 ]
# Accuarcy: 83.915468153801
# Average loss: 0.01422320658383147
# Model saved! (time elapsed: 538.8953020572662)
# [ Train epoch: 14 ]
# Train accuarcy: 78.57929111323108
# Train average loss: 0.018407637348675086
# [ Validation epoch: 15 ]
# Accuarcy: 79.36601115350749
# Average loss: 0.018838240003739768
# Model saved! (time elapsed: 577.7599642276764)
# [ Train epoch: 15 ]
# Train accuarcy: 79.21772950759521
# Train average loss: 0.017763545739814313
# [ Validation epoch: 16 ]
# Accuarcy: 84.26768417963018
# Average loss: 0.014009097812460566
# Model saved! (time elapsed: 616.1014084815979)
# [ Train epoch: 16 ]
# Train accuarcy: 78.73339693256035
# Train average loss: 0.017799319614796853
# [ Validation epoch: 17 ]
# Accuarcy: 83.56325212797182
# Average loss: 0.014076342630725752
# Model saved! (time elapsed: 654.9460322856903)
# [ Train epoch: 17 ]
# Train accuarcy: 79.66537022088501
# Train average loss: 0.01728120396997518
# [ Validation epoch: 18 ]
# Accuarcy: 84.29703551511594
# Average loss: 0.0141920483126331
# Model saved! (time elapsed: 693.10981965065)
# [ Train epoch: 18 ]
# Train accuarcy: 79.81213766786527
# Train average loss: 0.017152740172492336
# [ Validation epoch: 19 ]
# Accuarcy: 83.5045494570003
# Average loss: 0.015474532981544498
# Model saved! (time elapsed: 731.2687876224518)
# [ Train epoch: 19 ]
# Train accuarcy: 80.0616423277317
# Train average loss: 0.0167900440883521
# [ Validation epoch: 20 ]
# Accuarcy: 85.26562958614618
# Average loss: 0.012582436728799381
# Model saved! (time elapsed: 770.0607690811157)
# [ Train epoch: 20 ]
# Train accuarcy: 80.75144932853892
# Train average loss: 0.01656291742046467
# [ Validation epoch: 21 ]
# Accuarcy: 83.71000880540065
# Average loss: 0.014193447486620199
# Model saved! (time elapsed: 808.4437136650085)
# [ Train epoch: 21 ]
# Train accuarcy: 80.89087840317018
# Train average loss: 0.016415242292984765
# [ Validation epoch: 22 ]
# Accuarcy: 84.7373055474024
# Average loss: 0.013814642076307565
# Model saved! (time elapsed: 846.9106781482697)
# [ Train epoch: 22 ]
# Train accuarcy: 81.16239818008366
# Train average loss: 0.01601392097966358
# [ Validation epoch: 23 ]
# Accuarcy: 82.44790137951277
# Average loss: 0.015584561638129503
# Model saved! (time elapsed: 885.3291509151459)
# [ Train epoch: 23 ]
# Train accuarcy: 80.5606516474646
# Train average loss: 0.01623902197645933
# [ Validation epoch: 24 ]
# Accuarcy: 82.88817141179923
# Average loss: 0.015327774349076327
# Model saved! (time elapsed: 923.8374712467194)
# [ Train epoch: 24 ]
# Train accuarcy: 81.20642841417774
# Train average loss: 0.01602684424380489
# [ Validation epoch: 25 ]
# Accuarcy: 86.17552098620487
# Average loss: 0.012989903238990422
# Model saved! (time elapsed: 962.7378900051117)
# [ Train epoch: 25 ]
# Train accuarcy: 81.30916562706392
# Train average loss: 0.015744714557778997
# [ Validation epoch: 26 ]
# Accuarcy: 86.2342236571764
# Average loss: 0.0119337363259898
# Model saved! (time elapsed: 1001.0374772548676)
# [ Train epoch: 26 ]
# Train accuarcy: 81.73479122330667
# Train average loss: 0.015493273298738812
# [ Validation epoch: 27 ]
# Accuarcy: 86.6451423539771
# Average loss: 0.011712503452471774
# Model saved! (time elapsed: 1039.0804312229156)
# [ Train epoch: 27 ]
# Train accuarcy: 81.88889704263595
# Train average loss: 0.015678184238849754
# [ Validation epoch: 28 ]
# Accuarcy: 86.82125036689169
# Average loss: 0.01164615442929885
# Model saved! (time elapsed: 1077.3427352905273)
# [ Train epoch: 28 ]
# Train accuarcy: 81.71277610625962
# Train average loss: 0.015286918259064152
# [ Validation epoch: 29 ]
# Accuarcy: 84.76665688288817
# Average loss: 0.01308224256835727
# Model saved! (time elapsed: 1115.759536266327)
# [ Train epoch: 29 ]
# Train accuarcy: 82.2044470536435
# Train average loss: 0.015181290854700524
# [ Validation epoch: 30 ]
# Accuarcy: 85.50044027003229
# Average loss: 0.01304529748566171
# Model saved! (time elapsed: 1157.8828561306)
# [ Train epoch: 0 ]
# Train accuarcy: 45.5346004256256
# Train average loss: 0.04095968155533025
# [ Validation epoch: 1 ]
# Accuarcy: 58.203698268271204
# Average loss: 0.03305370553273906
# Model saved! (time elapsed: 72.88314437866211)
# [ Train epoch: 1 ]
# Train accuarcy: 56.35136126807074
# Train average loss: 0.034456942763272214
# [ Validation epoch: 2 ]
# Accuarcy: 57.46991488112709
# Average loss: 0.03322027198093393
# Model saved! (time elapsed: 146.29629921913147)
# [ Train epoch: 2 ]
# Train accuarcy: 61.03324282674103
# Train average loss: 0.03162918534476225
# [ Validation epoch: 3 ]
# Accuarcy: 66.68623422365718
# Average loss: 0.028092979300151588
# Model saved! (time elapsed: 219.74377059936523)
# [ Train epoch: 3 ]
# Train accuarcy: 64.70242900124752
# Train average loss: 0.02882201271640797
# [ Validation epoch: 4 ]
# Accuarcy: 66.97974757851482
# Average loss: 0.02646708080836465
# Model saved! (time elapsed: 292.5455038547516)
# [ Train epoch: 4 ]
# Train accuarcy: 66.5516988331988
# Train average loss: 0.027182786421126016
# [ Validation epoch: 5 ]
# Accuarcy: 73.17287936601116
# Average loss: 0.023468774462641947
# Model saved! (time elapsed: 365.49960017204285)
# [ Train epoch: 5 ]
# Train accuarcy: 69.08343729360828
# Train average loss: 0.025795126821671628
# [ Validation epoch: 6 ]
# Accuarcy: 76.25476959201643
# Average loss: 0.021340122058799548
# Model saved! (time elapsed: 438.2155957221985)
# [ Train epoch: 6 ]
# Train accuarcy: 71.2996257430102
# Train average loss: 0.024192367028164796
# [ Validation epoch: 7 ]
# Accuarcy: 79.57147050190784
# Average loss: 0.018371222037215158
# Model saved! (time elapsed: 510.99707293510437)
# [ Train epoch: 7 ]
# Train accuarcy: 72.42239671240918
# Train average loss: 0.02340582359989242
# [ Validation epoch: 8 ]
# Accuarcy: 78.95509245670678
# Average loss: 0.018499082638295753
# Model saved! (time elapsed: 583.7387177944183)
# [ Train epoch: 8 ]
# Train accuarcy: 72.9360827768401
# Train average loss: 0.022655917699403314
# [ Validation epoch: 9 ]
# Accuarcy: 77.7810390372762
# Average loss: 0.018590785101567822
# Model saved! (time elapsed: 656.1792483329773)
# [ Train epoch: 9 ]
# Train accuarcy: 74.2349746826154
# Train average loss: 0.0219598526259883
# [ Validation epoch: 10 ]
# Accuarcy: 78.63222776636337
# Average loss: 0.01944509687436302
# Model saved! (time elapsed: 732.4973981380463)
# [ Train epoch: 10 ]
# Train accuarcy: 73.83870257576869
# Train average loss: 0.021667903689284174
# [ Validation epoch: 11 ]
# Accuarcy: 80.51071323745231
# Average loss: 0.017386554044679283
# Model saved! (time elapsed: 809.5593032836914)
# [ Train epoch: 11 ]
# Train accuarcy: 74.93945842812064
# Train average loss: 0.02107603935132664
# [ Validation epoch: 12 ]
# Accuarcy: 78.95509245670678
# Average loss: 0.01793562484637782
# Model saved! (time elapsed: 886.3242311477661)
# [ Train epoch: 12 ]
# Train accuarcy: 75.82740148235122
# Train average loss: 0.020517137860345536
# [ Validation epoch: 13 ]
# Accuarcy: 80.62811857939536
# Average loss: 0.017180017429361046
# Model saved! (time elapsed: 964.5156207084656)
# [ Train epoch: 13 ]
# Train accuarcy: 76.37044103617818
# Train average loss: 0.01977632993287803
# [ Validation epoch: 14 ]
# Accuarcy: 83.12298209568536
# Average loss: 0.015452824683877986
# Model saved! (time elapsed: 1039.0863544940948)
# [ Train epoch: 14 ]
# Train accuarcy: 77.15564687752257
# Train average loss: 0.01931616878149978
# [ Validation epoch: 15 ]
# Accuarcy: 83.26973877311417
# Average loss: 0.015354305593226359
# Model saved! (time elapsed: 1113.2467772960663)
# [ Train epoch: 15 ]
# Train accuarcy: 77.94819109121597
# Train average loss: 0.01893512796715297
# [ Validation epoch: 16 ]
# Accuarcy: 80.86292926328147
# Average loss: 0.016498561247654035
# Model saved! (time elapsed: 1186.8651857376099)
# [ Train epoch: 16 ]
# Train accuarcy: 77.81610038893373
# Train average loss: 0.01902844575484238
# [ Validation epoch: 17 ]
# Accuarcy: 82.917522747285
# Average loss: 0.01545843412913218
# Model saved! (time elapsed: 1259.3776230812073)
# [ Train epoch: 17 ]
# Train accuarcy: 78.28575621927057
# Train average loss: 0.018430625645720865
# [ Validation epoch: 18 ]
# Accuarcy: 83.7393601408864
# Average loss: 0.014152233302155863
# Model saved! (time elapsed: 1332.7384786605835)
# [ Train epoch: 18 ]
# Train accuarcy: 78.28575621927057
# Train average loss: 0.018301267314921245
# [ Validation epoch: 19 ]
# Accuarcy: 80.54006457293806
# Average loss: 0.016997387113898667
# Model saved! (time elapsed: 1405.2159407138824)
# [ Train epoch: 19 ]
# Train accuarcy: 79.40118881632054
# Train average loss: 0.017690149046288746
# [ Validation epoch: 20 ]
# Accuarcy: 83.47519812151452
# Average loss: 0.014892709208857394
# Model saved! (time elapsed: 1477.8204696178436)
# [ Train epoch: 20 ]
# Train accuarcy: 78.63065971967417
# Train average loss: 0.017810747043799695
# [ Validation epoch: 21 ]
# Accuarcy: 84.20898150865864
# Average loss: 0.014463161443348395
# Model saved! (time elapsed: 1551.4784519672394)
# [ Train epoch: 21 ]
# Train accuarcy: 79.37917369927351
# Train average loss: 0.017629387715141536
# [ Validation epoch: 22 ]
# Accuarcy: 85.85265629586146
# Average loss: 0.012937439128314781
# Model saved! (time elapsed: 1624.2889995574951)
# [ Train epoch: 22 ]
# Train accuarcy: 79.84882952961033
# Train average loss: 0.016990590369551795
# [ Validation epoch: 23 ]
# Accuarcy: 85.73525095391841
# Average loss: 0.012580112915235704
# Model saved! (time elapsed: 1697.6937849521637)
# [ Train epoch: 23 ]
# Train accuarcy: 79.8268144125633
# Train average loss: 0.01712066839242914
# [ Validation epoch: 24 ]
# Accuarcy: 84.61990020545934
# Average loss: 0.013758443971690733
# Model saved! (time elapsed: 1770.240098953247)
# [ Train epoch: 24 ]
# Train accuarcy: 80.42122257283334
# Train average loss: 0.01681232728502008
# [ Validation epoch: 25 ]
# Accuarcy: 80.77487525682419
# Average loss: 0.017088951097403868
# Model saved! (time elapsed: 1842.7019300460815)
# [ Train epoch: 25 ]
# Train accuarcy: 80.54597490276656
# Train average loss: 0.01671994833172203
# [ Validation epoch: 26 ]
# Accuarcy: 81.39125330202525
# Average loss: 0.01598263310833274
# Model saved! (time elapsed: 1915.918292760849)
# [ Train epoch: 26 ]
# Train accuarcy: 80.2817934982021
# Train average loss: 0.016454022914365863
# [ Validation epoch: 27 ]
# Accuarcy: 84.47314352803052
# Average loss: 0.013474864246105566
# Model saved! (time elapsed: 1988.7657601833344)
# [ Train epoch: 27 ]
# Train accuarcy: 80.35517722169223
# Train average loss: 0.016369562433970912
# [ Validation epoch: 28 ]
# Accuarcy: 85.85265629586146
# Average loss: 0.012911929250078395
# Model saved! (time elapsed: 2061.037400484085)
# [ Train epoch: 28 ]
# Train accuarcy: 81.37521097820503
# Train average loss: 0.01565310118321217
# [ Validation epoch: 29 ]
# Accuarcy: 84.03287349574406
# Average loss: 0.014506227133174008
# Model saved! (time elapsed: 2133.535006046295)
# [ Train epoch: 29 ]
# Train accuarcy: 81.00829236075438
# Train average loss: 0.016105842084477684
# [ Validation epoch: 30 ]
# Accuarcy: 82.27179336659817
# Average loss: 0.01524759786619551
# Model saved! (time elapsed: 2206.0625505447388)

# %% [markdown]
# #### <b>(알아보기) ResNet 아키텍처 살펴보기</b>
#
# * [ResNet (2016 CVPR)](https://arxiv.org/abs/1512.03385) 논문에서 제안된 기본적인 ResNet의 핵심 아이디어를 PyTorch로 구현한 것은 다음과 같습니다.
#     * LightResNet에 비하여 <b>커널의 개수(number of kernels)가 많은</b> 것을 확인할 수 있습니다.
#     * 따라서 ImageNet과 같은 큰 규모의 데이터셋에 대해서 사용하기에 적합합니다.
# * (참고) [PyTorch 공식 ResNet 소스 코드](https://github.com/pytorch/vision/blob/master/torchvision/models/resnet.py)

# %%
# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=6):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        # 첫 레이어를 제외하고는 너비와 높이를 줄이기 위해 stride를 2로 설정
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1) # 첫째 블록만 너비와 높이 감소
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1) # 배치(batch)를 제외한 모든 차원 flatten하기
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])

# %% [markdown]
# #### <b>(알아보기) ResNet-18 학습하기</b>
#
# * PyTorch로 구현된 ResNet-18 모델을 학습해 봅시다.

# %%
import time
import torch.optim as optim


net = ResNet18()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "ResNet18.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 55.00843912820137
# Train average loss: 0.035288886842141896
# [ Validation epoch: 1 ]
# Accuarcy: 68.35926034634576
# Average loss: 0.02659507007027848
# Model saved! (time elapsed: 43.20541787147522)
# [ Train epoch: 1 ]
# Train accuarcy: 67.20481397226095
# Train average loss: 0.02725887120124345
# [ Validation epoch: 2 ]
# Accuarcy: 69.85617845611975
# Average loss: 0.026208706517215345
# Model saved! (time elapsed: 86.45038723945618)
# [ Train epoch: 2 ]
# Train accuarcy: 70.80061642327732
# Train average loss: 0.024509146132699774
# [ Validation epoch: 3 ]
# Accuarcy: 74.64044614029939
# Average loss: 0.02312257733728517
# Model saved! (time elapsed: 129.72964763641357)
# [ Train epoch: 3 ]
# Train accuarcy: 74.37440375724664
# Train average loss: 0.021764042556456444
# [ Validation epoch: 4 ]
# Accuarcy: 77.1940123275609
# Average loss: 0.0196509291637948
# Model saved! (time elapsed: 173.18718838691711)
# [ Train epoch: 4 ]
# Train accuarcy: 75.54854333308872
# Train average loss: 0.02091020165369272
# [ Validation epoch: 5 ]
# Accuarcy: 81.68476665688289
# Average loss: 0.01639623785162378
# Model saved! (time elapsed: 216.61494135856628)
# [ Train epoch: 5 ]
# Train accuarcy: 77.05290966463639
# Train average loss: 0.01943819641349618
# [ Validation epoch: 6 ]
# Accuarcy: 82.47725271499853
# Average loss: 0.016136170264594813
# Model saved! (time elapsed: 259.91014790534973)
# [ Train epoch: 6 ]
# Train accuarcy: 77.52256549497322
# Train average loss: 0.018970168166345343
# [ Validation epoch: 7 ]
# Accuarcy: 84.03287349574406
# Average loss: 0.013725004257048755
# Model saved! (time elapsed: 303.0229151248932)
# [ Train epoch: 7 ]
# Train accuarcy: 78.40317017685477
# Train average loss: 0.018155763470445084
# [ Validation epoch: 8 ]
# Accuarcy: 83.59260346345759
# Average loss: 0.01436726031002146
# Model saved! (time elapsed: 346.2467534542084)
# [ Train epoch: 8 ]
# Train accuarcy: 79.84149115726132
# Train average loss: 0.017382583592051217
# [ Validation epoch: 9 ]
# Accuarcy: 83.7393601408864
# Average loss: 0.01388131614773372
# Model saved! (time elapsed: 389.5548801422119)
# [ Train epoch: 9 ]
# Train accuarcy: 79.73141557202612
# Train average loss: 0.017289116454857534
# [ Validation epoch: 10 ]
# Accuarcy: 81.3325506310537
# Average loss: 0.016676680679401066
# Model saved! (time elapsed: 432.7722749710083)
# [ Train epoch: 10 ]
# Train accuarcy: 80.25977838115506
# Train average loss: 0.01695445070698351
# [ Validation epoch: 11 ]
# Accuarcy: 83.09363076019959
# Average loss: 0.015417955166299147
# Model saved! (time elapsed: 475.86610078811646)
# [ Train epoch: 11 ]
# Train accuarcy: 80.61202025390769
# Train average loss: 0.01637959227139771
# [ Validation epoch: 12 ]
# Accuarcy: 83.88611681831523
# Average loss: 0.014092657956728531
# Model saved! (time elapsed: 519.1564629077911)
# [ Train epoch: 12 ]
# Train accuarcy: 81.68342261686358
# Train average loss: 0.015869777056689204
# [ Validation epoch: 13 ]
# Accuarcy: 86.55708834751981
# Average loss: 0.012298705126835448
# Model saved! (time elapsed: 562.5714333057404)
# [ Train epoch: 13 ]
# Train accuarcy: 81.7494679680047
# Train average loss: 0.015441825415318803
# [ Validation epoch: 14 ]
# Accuarcy: 85.50044027003229
# Average loss: 0.01275643820693705
# Model saved! (time elapsed: 605.8693051338196)
# [ Train epoch: 14 ]
# Train accuarcy: 82.32186101122771
# Train average loss: 0.015191568545447658
# [ Validation epoch: 15 ]
# Accuarcy: 85.76460228940417
# Average loss: 0.012885313631984752
# Model saved! (time elapsed: 649.1161625385284)
# [ Train epoch: 15 ]
# Train accuarcy: 82.62273427753725
# Train average loss: 0.014857282322833707
# [ Validation epoch: 16 ]
# Accuarcy: 88.11270912826534
# Average loss: 0.010616472169717527
# Model saved! (time elapsed: 693.2337663173676)
# [ Train epoch: 16 ]
# Train accuarcy: 82.33653775592573
# Train average loss: 0.01493136243039167
# [ Validation epoch: 17 ]
# Accuarcy: 85.99941297329029
# Average loss: 0.012330161908924107
# Model saved! (time elapsed: 737.4608569145203)
# [ Train epoch: 17 ]
# Train accuarcy: 83.01900638438394
# Train average loss: 0.014359549537586468
# [ Validation epoch: 18 ]
# Accuarcy: 85.29498092163193
# Average loss: 0.013443081114590956
# Model saved! (time elapsed: 780.7729988098145)
# [ Train epoch: 18 ]
# Train accuarcy: 83.20980406545829
# Train average loss: 0.014116709274277085
# [ Validation epoch: 19 ]
# Accuarcy: 87.70179043146463
# Average loss: 0.011218593025315988
# Model saved! (time elapsed: 824.0784623622894)
# [ Train epoch: 19 ]
# Train accuarcy: 83.81155059807735
# Train average loss: 0.013665892509097721
# [ Validation epoch: 20 ]
# Accuarcy: 87.1441150572351
# Average loss: 0.011399330051371455
# Model saved! (time elapsed: 867.9163746833801)
# [ Train epoch: 20 ]
# Train accuarcy: 83.63542966170104
# Train average loss: 0.013992879355199585
# [ Validation epoch: 21 ]
# Accuarcy: 86.90930437334899
# Average loss: 0.011204377440000371
# Model saved! (time elapsed: 911.3979268074036)
# [ Train epoch: 21 ]
# Train accuarcy: 83.41527849123065
# Train average loss: 0.013835368444374234
# [ Validation epoch: 22 ]
# Accuarcy: 87.87789844437921
# Average loss: 0.010679156403843175
# Model saved! (time elapsed: 954.722416639328)
# [ Train epoch: 22 ]
# Train accuarcy: 83.98033316210464
# Train average loss: 0.013554135466641968
# [ Validation epoch: 23 ]
# Accuarcy: 87.93660111535075
# Average loss: 0.01120099414162948
# Model saved! (time elapsed: 999.486959695816)
# [ Train epoch: 23 ]
# Train accuarcy: 84.11242386438688
# Train average loss: 0.0133165807699767
# [ Validation epoch: 24 ]
# Accuarcy: 84.32638685060171
# Average loss: 0.013629913343199195
# Model saved! (time elapsed: 1044.3360526561737)
# [ Train epoch: 24 ]
# Train accuarcy: 84.55272620532766
# Train average loss: 0.013173513349555441
# [ Validation epoch: 25 ]
# Accuarcy: 87.93660111535075
# Average loss: 0.011224988148180593
# Model saved! (time elapsed: 1087.7557547092438)
# [ Train epoch: 25 ]
# Train accuarcy: 84.25919131136713
# Train average loss: 0.013073752326337925
# [ Validation epoch: 26 ]
# Accuarcy: 88.46492515409452
# Average loss: 0.010476856102928025
# Model saved! (time elapsed: 1130.9112694263458)
# [ Train epoch: 26 ]
# Train accuarcy: 85.24253320613488
# Train average loss: 0.012547800303327807
# [ Validation epoch: 27 ]
# Accuarcy: 87.99530378632228
# Average loss: 0.010921210212409408
# Model saved! (time elapsed: 1174.253363609314)
# [ Train epoch: 27 ]
# Train accuarcy: 84.58207969472372
# Train average loss: 0.012739729932025146
# [ Validation epoch: 28 ]
# Accuarcy: 89.43351922512474
# Average loss: 0.009622232468554377
# Model saved! (time elapsed: 1217.5968561172485)
# [ Train epoch: 28 ]
# Train accuarcy: 85.16914948264476
# Train average loss: 0.012458822461613435
# [ Validation epoch: 29 ]
# Accuarcy: 86.76254769592016
# Average loss: 0.012290189548395301
# Model saved! (time elapsed: 1260.7223227024078)
# [ Train epoch: 29 ]
# Train accuarcy: 85.40397739781316
# Train average loss: 0.012309584260061235
# [ Validation epoch: 30 ]
# Accuarcy: 89.46287056061051
# Average loss: 0.009610090149981486
# Model saved! (time elapsed: 1304.4205510616302)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = ResNet18()
net = net.to(device)

file_name = "./checkpoint/ResNet18.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.8642, 0.9759, 0.8333, 0.8915, 0.8732, 0.9323])
# [ 전체 평균 정확도 ]
# tensor(0.8946)

# %% [markdown]
# #### <b>(알아보기) Input Mixup 살펴보기</b>
#
# * Mixup은 대표적인 데이터 증진(data augmentation) 기법으로 정확도 향상에 도움이 됩니다.
#     * 일반적으로 Mixup을 사용하는 경우 더 많은 횟수(1.5배가량)의 epoch이 요구됩니다.

# %%
mixup_alpha = 1.0


def mixup_data(x, y):
    lam = np.random.beta(mixup_alpha, mixup_alpha)
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).cuda()
    mixed_x = lam * x + (1 - lam) * x[index]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)


def train_with_mixup(net, epoch, optimizer, criterion, train_dataloader):
    print('[ Train epoch: %d ]' % epoch)
    net.train() # 모델을 학습 모드로 설정
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_dataloader):
        inputs, targets = inputs.to(device), targets.to(device)
        inputs, targets_a, targets_b, lam = mixup_data(inputs, targets) # Mixup 진행
        optimizer.zero_grad() # 기울기(gradient) 초기화

        outputs = net(inputs) # 모델 입력하여 결과 계산
        loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam) # 손실(loss) 값 계산
        loss.backward() # 역전파를 통해 기울기(gradient) 계산

        optimizer.step() # 계산된 기울기를 이용해 모델 가중치 업데이트
        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += (lam * predicted.eq(targets_a).sum().item() + (1 - lam) * predicted.eq(targets_b).sum().item())

    print('Train accuarcy:', 100. * correct / total)
    print('Train average loss:', train_loss / total)
    return (100. * correct / total, train_loss / total)

# %% [markdown]
# #### <b>Problem 6. Mixup 결과 분석하기</b>
#
# * Mixup을 사용하여 ResNet-18에 대하여 50번 epoch만큼 학습을 진행한 뒤에 성능이 얼마나 개선되었는지 쓰세요.
#     * Mixup을 적용했을 때의 검증 정확도(validation accuracy): 88.84

# %%
train_dataset = datasets.ImageFolder(train_path, transforms_train)
val_dataset = datasets.ImageFolder(val_path, transforms_val)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=True, num_workers=2)


net = ResNet18()
net = net.to(device)

epoch = 50
learning_rate = 0.002
file_name = "ResNet18_mixup.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train_with_mixup(net, i, optimizer, criterion, train_dataloader)
    val_acc, val_loss = validate(net, i + 1, val_dataloader)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 43.05317698366259
# Train average loss: 0.045407980573302434
# [ Validation epoch: 1 ]
# Accuarcy: 59.11358966832991
# Average loss: 0.03213825336396957
# Model saved! (time elapsed: 43.373435497283936)
# [ Train epoch: 1 ]
# Train accuarcy: 51.61576500826792
# Train average loss: 0.04049113990101066
# [ Validation epoch: 2 ]
# Accuarcy: 62.87056061050778
# Average loss: 0.029593117922185837
# Model saved! (time elapsed: 86.85492992401123)
# [ Train epoch: 2 ]
# Train accuarcy: 54.721946880241205
# Train average loss: 0.03885949199054634
# [ Validation epoch: 3 ]
# Accuarcy: 76.31347226298797
# Average loss: 0.022383027843691436
# Model saved! (time elapsed: 130.24142384529114)
# [ Train epoch: 3 ]
# Train accuarcy: 56.65256427789981
# Train average loss: 0.0374861949475345
# [ Validation epoch: 4 ]
# Accuarcy: 74.69914881127092
# Average loss: 0.02353839652783926
# Model saved! (time elapsed: 173.6575095653534)
# [ Train epoch: 4 ]
# Train accuarcy: 57.5559083702335
# Train average loss: 0.037003842043650946
# [ Validation epoch: 5 ]
# Accuarcy: 76.95920164367479
# Average loss: 0.021596254370308425
# Model saved! (time elapsed: 217.2294580936432)
# [ Train epoch: 5 ]
# Train accuarcy: 58.35967357769161
# Train average loss: 0.036410615013255807
# [ Validation epoch: 6 ]
# Accuarcy: 72.85001467566774
# Average loss: 0.02333020358306766
# Model saved! (time elapsed: 260.80447340011597)
# [ Train epoch: 6 ]
# Train accuarcy: 58.90316467273016
# Train average loss: 0.035924662720599826
# [ Validation epoch: 7 ]
# Accuarcy: 73.5544467273261
# Average loss: 0.024326410458379733
# Model saved! (time elapsed: 304.329745054245)
# [ Train epoch: 7 ]
# Train accuarcy: 59.050639219131696
# Train average loss: 0.03594833677614777
# [ Validation epoch: 8 ]
# Accuarcy: 74.90460815967127
# Average loss: 0.0214646745627319
# Model saved! (time elapsed: 347.85883951187134)
# [ Train epoch: 8 ]
# Train accuarcy: 59.9259665301216
# Train average loss: 0.03501449902724072
# [ Validation epoch: 9 ]
# Accuarcy: 83.09363076019959
# Average loss: 0.016878353331772716
# Model saved! (time elapsed: 391.37008023262024)
# [ Train epoch: 9 ]
# Train accuarcy: 60.587234560958805
# Train average loss: 0.03453284496124504
# [ Validation epoch: 10 ]
# Accuarcy: 84.15027883768711
# Average loss: 0.01724296787249087
# Model saved! (time elapsed: 434.88080525398254)
# [ Train epoch: 10 ]
# Train accuarcy: 60.328791485704926
# Train average loss: 0.03456798774083152
# [ Validation epoch: 11 ]
# Accuarcy: 82.5946580569416
# Average loss: 0.017719023539798155
# Model saved! (time elapsed: 478.45217752456665)
# [ Train epoch: 11 ]
# Train accuarcy: 61.402985106738
# Train average loss: 0.03448035032127891
# [ Validation epoch: 12 ]
# Accuarcy: 81.74346932785441
# Average loss: 0.017648954938365668
# Model saved! (time elapsed: 522.0729999542236)
# [ Train epoch: 12 ]
# Train accuarcy: 62.12471315391818
# Train average loss: 0.033421354713465835
# [ Validation epoch: 13 ]
# Accuarcy: 83.76871147637218
# Average loss: 0.016830466090670633
# Model saved! (time elapsed: 565.6523900032043)
# [ Train epoch: 13 ]
# Train accuarcy: 62.23557959540561
# Train average loss: 0.03324170392371592
# [ Validation epoch: 14 ]
# Accuarcy: 82.47725271499853
# Average loss: 0.016024935807970427
# Model saved! (time elapsed: 609.4699838161469)
# [ Train epoch: 14 ]
# Train accuarcy: 61.44880913916919
# Train average loss: 0.033792304421429976
# [ Validation epoch: 15 ]
# Accuarcy: 84.913413560317
# Average loss: 0.017139402982738663
# Model saved! (time elapsed: 653.2427020072937)
# [ Train epoch: 15 ]
# Train accuarcy: 62.6047799540779
# Train average loss: 0.032996400358602206
# [ Validation epoch: 16 ]
# Accuarcy: 85.03081890226005
# Average loss: 0.01588770028150148
# Model saved! (time elapsed: 696.9364705085754)
# [ Train epoch: 16 ]
# Train accuarcy: 61.57468152459199
# Train average loss: 0.03370603747786714
# [ Validation epoch: 17 ]
# Accuarcy: 84.79600821837394
# Average loss: 0.015893203852846365
# Model saved! (time elapsed: 740.500983953476)
# [ Train epoch: 17 ]
# Train accuarcy: 63.13246911368836
# Train average loss: 0.03256236585043685
# [ Validation epoch: 18 ]
# Accuarcy: 86.41033167009098
# Average loss: 0.014920070701797301
# Model saved! (time elapsed: 784.040105342865)
# [ Train epoch: 18 ]
# Train accuarcy: 63.821015465692156
# Train average loss: 0.031975994325221274
# [ Validation epoch: 19 ]
# Accuarcy: 84.38508952157324
# Average loss: 0.016095152266360744
# Model saved! (time elapsed: 827.5462794303894)
# [ Train epoch: 19 ]
# Train accuarcy: 63.24624387704719
# Train average loss: 0.0324938955341649
# [ Validation epoch: 20 ]
# Accuarcy: 84.38508952157324
# Average loss: 0.016140970669081038
# Model saved! (time elapsed: 871.1508271694183)
# [ Train epoch: 20 ]
# Train accuarcy: 63.77226129516862
# Train average loss: 0.031990513099458495
# [ Validation epoch: 21 ]
# Accuarcy: 79.6008218373936
# Average loss: 0.018544177278452055
# Model saved! (time elapsed: 914.7454574108124)
# [ Train epoch: 21 ]
# Train accuarcy: 62.83408918117004
# Train average loss: 0.032578551894790704
# [ Validation epoch: 22 ]
# Accuarcy: 86.20487232169064
# Average loss: 0.014373058215382864
# Model saved! (time elapsed: 958.4665999412537)
# [ Train epoch: 22 ]
# Train accuarcy: 63.25530276584247
# Train average loss: 0.03224918377489549
# [ Validation epoch: 23 ]
# Accuarcy: 80.04109186968007
# Average loss: 0.018227016694880947
# Model saved! (time elapsed: 1002.1191141605377)
# [ Train epoch: 23 ]
# Train accuarcy: 64.38305341410235
# Train average loss: 0.031629404344920536
# [ Validation epoch: 24 ]
# Accuarcy: 88.14206046375111
# Average loss: 0.01375527388632455
# Model saved! (time elapsed: 1045.8037190437317)
# [ Train epoch: 24 ]
# Train accuarcy: 64.25837098342497
# Train average loss: 0.03178269651907682
# [ Validation epoch: 25 ]
# Accuarcy: 86.6451423539771
# Average loss: 0.014338184450951216
# Model saved! (time elapsed: 1089.4961128234863)
# [ Train epoch: 25 ]
# Train accuarcy: 63.77744853449365
# Train average loss: 0.03176286904514601
# [ Validation epoch: 26 ]
# Accuarcy: 84.94276489580275
# Average loss: 0.015899262191754547
# Model saved! (time elapsed: 1133.052964925766)
# [ Train epoch: 26 ]
# Train accuarcy: 64.4420684786869
# Train average loss: 0.03145255127087494
# [ Validation epoch: 27 ]
# Accuarcy: 87.29087173466392
# Average loss: 0.014206289571507921
# Model saved! (time elapsed: 1176.5639848709106)
# [ Train epoch: 27 ]
# Train accuarcy: 65.62009801202544
# Train average loss: 0.030879994192625198
# [ Validation epoch: 28 ]
# Accuarcy: 87.6430877604931
# Average loss: 0.013582590220609227
# Model saved! (time elapsed: 1220.2064361572266)
# [ Train epoch: 28 ]
# Train accuarcy: 63.81809761390432
# Train average loss: 0.031734500105771
# [ Validation epoch: 29 ]
# Accuarcy: 82.74141473437041
# Average loss: 0.017015589151278876
# Model saved! (time elapsed: 1263.829538822174)
# [ Train epoch: 29 ]
# Train accuarcy: 64.68251198780187
# Train average loss: 0.031068622444838958
# [ Validation epoch: 30 ]
# Accuarcy: 87.05606105077781
# Average loss: 0.014674886733092344
# Model saved! (time elapsed: 1307.319892168045)
# [ Train epoch: 30 ]
# Train accuarcy: 65.56369689221249
# Train average loss: 0.030656023878707236
# [ Validation epoch: 31 ]
# Accuarcy: 86.61579101849134
# Average loss: 0.01392442292837513
# Model saved! (time elapsed: 1350.889286518097)
# [ Train epoch: 31 ]
# Train accuarcy: 64.88521839877872
# Train average loss: 0.03098190467854698
# [ Validation epoch: 32 ]
# Accuarcy: 87.90724977986498
# Average loss: 0.014136453090541203
# Model saved! (time elapsed: 1394.510318994522)
# [ Train epoch: 32 ]
# Train accuarcy: 65.7275423766134
# Train average loss: 0.0305427586489066
# [ Validation epoch: 33 ]
# Accuarcy: 87.46697974757852
# Average loss: 0.0148070631119594
# Model saved! (time elapsed: 1438.2862622737885)
# [ Train epoch: 33 ]
# Train accuarcy: 64.89892469543369
# Train average loss: 0.030777691084561593
# [ Validation epoch: 34 ]
# Accuarcy: 87.58438508952158
# Average loss: 0.01377168490209991
# Model saved! (time elapsed: 1481.9282188415527)
# [ Train epoch: 34 ]
# Train accuarcy: 66.49763728362517
# Train average loss: 0.02993226148652306
# [ Validation epoch: 35 ]
# Accuarcy: 87.81919577340769
# Average loss: 0.013792058821993906
# Model saved! (time elapsed: 1525.5316410064697)
# [ Train epoch: 35 ]
# Train accuarcy: 65.74743573243835
# Train average loss: 0.030189419202569418
# [ Validation epoch: 36 ]
# Accuarcy: 87.3202230701497
# Average loss: 0.014138014064809253
# Model saved! (time elapsed: 1569.11270570755)
# [ Train epoch: 36 ]
# Train accuarcy: 65.52090193147137
# Train average loss: 0.030271561959173514
# [ Validation epoch: 37 ]
# Accuarcy: 88.5529791605518
# Average loss: 0.013136274996726156
# Model saved! (time elapsed: 1613.3097388744354)
# [ Train epoch: 37 ]
# Train accuarcy: 64.92484760930257
# Train average loss: 0.030735915419447753
# [ Validation epoch: 38 ]
# Accuarcy: 87.43762841209275
# Average loss: 0.014642811124192539
# Model saved! (time elapsed: 1656.9942400455475)
# [ Train epoch: 38 ]
# Train accuarcy: 64.47652808806674
# Train average loss: 0.030909946114929282
# [ Validation epoch: 39 ]
# Accuarcy: 88.5529791605518
# Average loss: 0.013324757160453247
# Model saved! (time elapsed: 1700.487576007843)
# [ Train epoch: 39 ]
# Train accuarcy: 65.94193178423879
# Train average loss: 0.030267133355280654
# [ Validation epoch: 40 ]
# Accuarcy: 84.7373055474024
# Average loss: 0.016099445572128945
# Model saved! (time elapsed: 1744.1457567214966)
# [ Train epoch: 40 ]
# Train accuarcy: 66.44869730448964
# Train average loss: 0.02989743526065709
# [ Validation epoch: 41 ]
# Accuarcy: 88.43557381860875
# Average loss: 0.013294676505193215
# Model saved! (time elapsed: 1787.6609485149384)
# [ Train epoch: 41 ]
# Train accuarcy: 65.96861606411862
# Train average loss: 0.0301738905151723
# [ Validation epoch: 42 ]
# Accuarcy: 88.58233049603757
# Average loss: 0.013220095926622929
# Model saved! (time elapsed: 1831.3178803920746)
# [ Train epoch: 42 ]
# Train accuarcy: 66.39360802109798
# Train average loss: 0.029940038197737075
# [ Validation epoch: 43 ]
# Accuarcy: 85.91135896683299
# Average loss: 0.014734715127091203
# Model saved! (time elapsed: 1874.8791348934174)
# [ Train epoch: 43 ]
# Train accuarcy: 66.92315539523439
# Train average loss: 0.029693095137475128
# [ Validation epoch: 44 ]
# Accuarcy: 86.87995303786322
# Average loss: 0.013108882253772533
# Model saved! (time elapsed: 1918.357986688614)
# [ Train epoch: 44 ]
# Train accuarcy: 64.83024308491233
# Train average loss: 0.03064163025147918
# [ Validation epoch: 45 ]
# Accuarcy: 85.44173759906076
# Average loss: 0.015120892317231394
# Model saved! (time elapsed: 1961.888150691986)
# [ Train epoch: 45 ]
# Train accuarcy: 65.89674914532702
# Train average loss: 0.029777090179383944
# [ Validation epoch: 46 ]
# Accuarcy: 88.17141179923686
# Average loss: 0.012878658950311333
# Model saved! (time elapsed: 2005.6035947799683)
# [ Train epoch: 46 ]
# Train accuarcy: 67.27409294417814
# Train average loss: 0.029193294563786495
# [ Validation epoch: 47 ]
# Accuarcy: 87.52568241855005
# Average loss: 0.01367834935553584
# Model saved! (time elapsed: 2049.1865096092224)
# [ Train epoch: 47 ]
# Train accuarcy: 66.8799312571608
# Train average loss: 0.029369838461974242
# [ Validation epoch: 48 ]
# Accuarcy: 87.52568241855005
# Average loss: 0.014431913559619444
# Model saved! (time elapsed: 2092.6400275230408)
# [ Train epoch: 48 ]
# Train accuarcy: 66.592032120992
# Train average loss: 0.029477500052535018
# [ Validation epoch: 49 ]
# Accuarcy: 87.40827707660698
# Average loss: 0.013408188499556212
# Model saved! (time elapsed: 2136.27587556839)
# [ Train epoch: 49 ]
# Train accuarcy: 66.68084531453484
# Train average loss: 0.02944580201200915
# [ Validation epoch: 50 ]
# Accuarcy: 88.81714117992368
# Average loss: 0.013358829441852921
# Model saved! (time elapsed: 2179.8376030921936)

# %% [markdown]
# #### <b>(알아보기) Transfer Learning 살펴보기</b>
#
# * 전이 학습(Transfer Learning)은 <b>단기간에 우수한 정확도</b>를 얻기 위해 효과적으로 사용할 수 있는 기법입니다.
#     * 본 실습에서는 미세 조정(fine-tuning) 기법을 사용합니다.
#     * 적은 epoch만으로도 빠르게 수렴합니다.
# * 전이 학습을 위해서는, 사전 학습된(pre-trained) 네트워크와 동일한 크기의 입력 차원을 갖도록 <b>데이터셋을 수정</b>해야 합니다.
#     * ResNet 특성상 데이터셋 수정 없이도 동작할 수 있지만, 일반적으로 데이터셋을 수정합니다.
# * (참고) [PyTorch 공식 Transfer Learning 튜토리얼](https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html)
# * 기본적인 Transfer Learning을 이용해 91~93%의 정확도를 얻을 수 있습니다.

# %%
transforms_train_transferred = transforms.Compose([
    transforms.RandomResizedCrop((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

transforms_val_transferred = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset_transferred = datasets.ImageFolder(train_path, transforms_train_transferred)
val_dataset_transferred = datasets.ImageFolder(val_path, transforms_val_transferred)

train_dataloader_transferred = torch.utils.data.DataLoader(train_dataset_transferred, batch_size=16, shuffle=True, num_workers=2)
val_dataloader_transferred = torch.utils.data.DataLoader(val_dataset_transferred, batch_size=16, shuffle=True, num_workers=2)

print('Training dataset size:', len(train_dataset_transferred))
print('Validation dataset size:', len(val_dataset_transferred))

class_names = train_dataset_transferred.classes
print('Class names:', class_names)
# Out:
# Training dataset size: 13627
# Validation dataset size: 3407
# Class names: ['buildings', 'forests', 'glacier', 'mountains', 'sea', 'street']

# %%
net = torchvision.models.resnet18(pretrained=True)

# 마지막 레이어의 차원을 6차원으로 조절
num_features = net.fc.in_features
net.fc = nn.Linear(num_features, 6)
net = net.to(device)

epoch = 20
learning_rate = 0.001 # 일반적으로 fine-tuning을 진행할 때는 학습률(learning rate)을 낮게 설정
file_name = "ResNet18Transferred.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader_transferred) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader_transferred) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# [ Train epoch: 0 ]
# Train accuarcy: 76.45116313201731
# Train average loss: 0.040072278380765776
# [ Validation epoch: 1 ]
# Accuarcy: 88.87584385089522
# Average loss: 0.018948719074382683
# Model saved! (time elapsed: 57.41907596588135)
# [ Train epoch: 1 ]
# Train accuarcy: 82.7181331180744
# Train average loss: 0.02882006205030624
# [ Validation epoch: 2 ]
# Accuarcy: 90.25535661872615
# Average loss: 0.017685203243616672
# Model saved! (time elapsed: 117.12636160850525)
# [ Train epoch: 2 ]
# Train accuarcy: 84.25185293901812
# Train average loss: 0.026785039854220708
# [ Validation epoch: 3 ]
# Accuarcy: 91.57616671558556
# Average loss: 0.015488197813797355
# Model saved! (time elapsed: 177.0421667098999)
# [ Train epoch: 3 ]
# Train accuarcy: 85.7635576429148
# Train average loss: 0.02479626214835792
# [ Validation epoch: 4 ]
# Accuarcy: 91.78162606398591
# Average loss: 0.015216808271899683
# Model saved! (time elapsed: 232.28720927238464)
# [ Train epoch: 4 ]
# Train accuarcy: 86.09378439862039
# Train average loss: 0.02351416659093707
# [ Validation epoch: 5 ]
# Accuarcy: 92.13384208981509
# Average loss: 0.014455465954163398
# Model saved! (time elapsed: 286.7150077819824)
# [ Train epoch: 5 ]
# Train accuarcy: 87.1211565274822
# Train average loss: 0.021815716882550754
# [ Validation epoch: 6 ]
# Accuarcy: 92.4567067801585
# Average loss: 0.01376211440826498
# Model saved! (time elapsed: 341.75388765335083)
# [ Train epoch: 6 ]
# Train accuarcy: 87.77427166654437
# Train average loss: 0.020929839400942393
# [ Validation epoch: 7 ]
# Accuarcy: 93.01438215438803
# Average loss: 0.013777296442351525
# Model saved! (time elapsed: 396.17775797843933)
# [ Train epoch: 7 ]
# Train accuarcy: 87.67153445365818
# Train average loss: 0.020647820911291692
# [ Validation epoch: 8 ]
# Accuarcy: 92.13384208981509
# Average loss: 0.014241943319962588
# Model saved! (time elapsed: 450.6393027305603)
# [ Train epoch: 8 ]
# Train accuarcy: 88.44940192265355
# Train average loss: 0.019660681338643585
# [ Validation epoch: 9 ]
# Accuarcy: 92.8676254769592
# Average loss: 0.013487923987940202
# Model saved! (time elapsed: 505.0463795661926)
# [ Train epoch: 9 ]
# Train accuarcy: 88.77962867835915
# Train average loss: 0.019116593841109305
# [ Validation epoch: 10 ]
# Accuarcy: 92.19254476078662
# Average loss: 0.013958507003702741
# Model saved! (time elapsed: 560.2192223072052)
# [ Train epoch: 10 ]
# Train accuarcy: 89.10251706171572
# Train average loss: 0.0182605062299001
# [ Validation epoch: 11 ]
# Accuarcy: 93.16113883181684
# Average loss: 0.013278170266810019
# Model saved! (time elapsed: 614.5823132991791)
# [ Train epoch: 11 ]
# Train accuarcy: 89.6602333602407
# Train average loss: 0.017491281665016876
# [ Validation epoch: 12 ]
# Accuarcy: 92.19254476078662
# Average loss: 0.014204784749949961
# Model saved! (time elapsed: 669.2984087467194)
# [ Train epoch: 12 ]
# Train accuarcy: 89.81433917956997
# Train average loss: 0.017267605546174895
# [ Validation epoch: 13 ]
# Accuarcy: 92.33930143821544
# Average loss: 0.015259476646516907
# Model saved! (time elapsed: 724.4837112426758)
# [ Train epoch: 13 ]
# Train accuarcy: 90.21061128641668
# Train average loss: 0.01678275763786197
# [ Validation epoch: 14 ]
# Accuarcy: 93.24919283827414
# Average loss: 0.01417758572311694
# Model saved! (time elapsed: 778.9400079250336)
# [ Train epoch: 14 ]
# Train accuarcy: 89.90973802010714
# Train average loss: 0.016634409592027714
# [ Validation epoch: 15 ]
# Accuarcy: 92.48605811564425
# Average loss: 0.014726639029167817
# Model saved! (time elapsed: 833.4517407417297)
# [ Train epoch: 15 ]
# Train accuarcy: 90.06384383943642
# Train average loss: 0.01667027772574635
# [ Validation epoch: 16 ]
# Accuarcy: 90.37276196066921
# Average loss: 0.01623396680091426
# Model saved! (time elapsed: 888.8233761787415)
# [ Train epoch: 16 ]
# Train accuarcy: 90.83437293608277
# Train average loss: 0.01538562909972327
# [ Validation epoch: 17 ]
# Accuarcy: 92.48605811564425
# Average loss: 0.01436118563702196
# Model saved! (time elapsed: 943.5666387081146)
# [ Train epoch: 17 ]
# Train accuarcy: 91.15726131943934
# Train average loss: 0.015126163109867984
# [ Validation epoch: 18 ]
# Accuarcy: 92.01643674787204
# Average loss: 0.016529820151236167
# Model saved! (time elapsed: 998.244725227356)
# [ Train epoch: 18 ]
# Train accuarcy: 90.94444852131797
# Train average loss: 0.015503408444712244
# [ Validation epoch: 19 ]
# Accuarcy: 92.60346345758732
# Average loss: 0.015052116349094011
# Model saved! (time elapsed: 1052.7738237380981)
# [ Train epoch: 19 ]
# Train accuarcy: 90.86372642547883
# Train average loss: 0.014718133456172731
# [ Validation epoch: 20 ]
# Accuarcy: 93.04373348987379
# Average loss: 0.013981856421000218
# Model saved! (time elapsed: 1108.1806108951569)

# %% [markdown]
# #### <b>Problem 7. State-of-the-Art 성능 만들기</b>
#
# * SOTA 수준의 성능을 만들어 보세요.
# * (참고) Transfer Learning과 Mixup을 함께 사용해 보세요.
#     * 더 큰 규모의 사전 학습된 모델(ResNet-50 이상)을 이용해 보세요.
# * (참고) learning rate scheduler를 사용해 보세요.
#
# <pre>
# def adjust_learning_rate(optimizer, epoch):
#     lr = learning_rate
#     if epoch >= 20:
#         lr /= 8
#     if epoch >= 40:
#         lr /= 8
#     for param_group in optimizer.param_groups:
#         param_group['lr'] = lr
# </pre>
#
# * 대회(competition)에 참여하고 있다고 생각하고, <b>94% 이상의 정확도</b>를 만들어 보세요.
#     * 내 모델의 검증 정확도(validation accuracy): 94.04%

# %%
transforms_train_transferred = transforms.Compose([
    transforms.RandomResizedCrop((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

transforms_val_transferred = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset_transferred = datasets.ImageFolder(train_path, transforms_train_transferred)
val_dataset_transferred = datasets.ImageFolder(val_path, transforms_val_transferred)

train_dataloader_transferred = torch.utils.data.DataLoader(train_dataset_transferred, batch_size=16, shuffle=True, num_workers=2)
val_dataloader_transferred = torch.utils.data.DataLoader(val_dataset_transferred, batch_size=16, shuffle=True, num_workers=2)

print('Training dataset size:', len(train_dataset_transferred))
print('Validation dataset size:', len(val_dataset_transferred))

class_names = train_dataset_transferred.classes
print('Class names:', class_names)

def validate(net, epoch, val_dataloader):
    print('[ Validation epoch: %d ]' % epoch)
    net.eval() # 모델을 평가 모드로 설정
    val_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(val_dataloader):
        inputs, targets = inputs.to(device), targets.to(device)

        outputs = net(inputs) # 모델 입력하여 결과 계산
        val_loss += criterion(outputs, targets).item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    print('Accuarcy:', 100. * correct / total)
    print('Average loss:', val_loss / total)
    return (100. * correct / total, val_loss / total)



mixup_alpha = 1.0


def mixup_data(x, y):
    lam = np.random.beta(mixup_alpha, mixup_alpha)
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).cuda()
    mixed_x = lam * x + (1 - lam) * x[index]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)


def train_with_mixup(net, epoch, optimizer, criterion, train_dataloader):
    print('[ Train epoch: %d ]' % epoch)
    net.train() # 모델을 학습 모드로 설정
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_dataloader):
        inputs, targets = inputs.to(device), targets.to(device)
        inputs, targets_a, targets_b, lam = mixup_data(inputs, targets) # Mixup 진행
        optimizer.zero_grad() # 기울기(gradient) 초기화

        outputs = net(inputs) # 모델 입력하여 결과 계산
        loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam) # 손실(loss) 값 계산
        loss.backward() # 역전파를 통해 기울기(gradient) 계산

        optimizer.step() # 계산된 기울기를 이용해 모델 가중치 업데이트
        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += (lam * predicted.eq(targets_a).sum().item() + (1 - lam) * predicted.eq(targets_b).sum().item())

    print('Train accuarcy:', 100. * correct / total)
    print('Train average loss:', train_loss / total)
    return (100. * correct / total, train_loss / total)



def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 20:
        lr /= 8
    if epoch >= 40:
        lr /= 8
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr


net = torchvision.models.resnet18(pretrained=True)

# 마지막 레이어의 차원을 6차원으로 조절
num_features = net.fc.in_features
net.fc = nn.Linear(num_features, 6)
net = net.to(device)

epoch = 100
learning_rate = 0.01
file_name = "Mymodel.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train_with_mixup(net, i, optimizer, criterion, train_dataloader_transferred) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader_transferred) # 검증(validation)
    adjust_learning_rate(optimizer,i)
    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# Training dataset size: 13627
# Validation dataset size: 3407
# Class names: ['buildings', 'forests', 'glacier', 'mountains', 'sea', 'street']
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [ Train epoch: 0 ]
# Train accuarcy: 46.55509119391389
# Train average loss: 0.09518133915991954
# [ Validation epoch: 1 ]
# Accuarcy: 81.89022600528324
# Average loss: 0.03704106261434883
# Model saved! (time elapsed: 56.245275259017944)
# [ Train epoch: 1 ]
# Train accuarcy: 57.49497685744689
# Train average loss: 0.07620910904225017
# [ Validation epoch: 2 ]
# Accuarcy: 66.89169357205753
# Average loss: 0.22044157664342678
# Model saved! (time elapsed: 111.79075837135315)
# [ Train epoch: 2 ]
# Train accuarcy: 60.53578364204859
# Train average loss: 0.0716784782338634
# [ Validation epoch: 3 ]
# Accuarcy: 81.86087466979748
# Average loss: 0.052818787790723375
# Model saved! (time elapsed: 167.36061429977417)
# [ Train epoch: 3 ]
# Train accuarcy: 61.974315700796815
# Train average loss: 0.06913934880624979
# [ Validation epoch: 4 ]
# Accuarcy: 85.3243322571177
# Average loss: 0.0336082895978791
# Model saved! (time elapsed: 223.34547424316406)
# [ Train epoch: 4 ]
# Train accuarcy: 62.59548440790515
# Train average loss: 0.06821494752849688
# [ Validation epoch: 5 ]
# Accuarcy: 88.25946580569416
# Average loss: 0.026579823007078368
# Model saved! (time elapsed: 278.99808502197266)
# [ Train epoch: 5 ]
# Train accuarcy: 62.759836077998735
# Train average loss: 0.06769680089818292
# [ Validation epoch: 6 ]
# Accuarcy: 88.46492515409452
# Average loss: 0.02619888313554199
# Model saved! (time elapsed: 334.3601875305176)
# [ Train epoch: 6 ]
# Train accuarcy: 63.67237046273855
# Train average loss: 0.06637728807817178
# [ Validation epoch: 7 ]
# Accuarcy: 85.38303492808923
# Average loss: 0.029106527260751504
# Model saved! (time elapsed: 390.03548526763916)
# [ Train epoch: 7 ]
# Train accuarcy: 63.79648467364185
# Train average loss: 0.06545060956575222
# [ Validation epoch: 8 ]
# Accuarcy: 88.61168183152333
# Average loss: 0.025602363283976384
# Model saved! (time elapsed: 445.3693296909332)
# [ Train epoch: 8 ]
# Train accuarcy: 63.5644359529689
# Train average loss: 0.06529471265943383
# [ Validation epoch: 9 ]
# Accuarcy: 89.22805987672439
# Average loss: 0.024879762498836278
# Model saved! (time elapsed: 501.26716351509094)
# [ Train epoch: 9 ]
# Train accuarcy: 65.58162336611527
# Train average loss: 0.06281001009323141
# [ Validation epoch: 10 ]
# Accuarcy: 86.29292632814793
# Average loss: 0.03033169618109856
# Model saved! (time elapsed: 556.5626270771027)
# [ Train epoch: 10 ]
# Train accuarcy: 65.54562944770936
# Train average loss: 0.06230871100641621
# [ Validation epoch: 11 ]
# Accuarcy: 88.67038450249487
# Average loss: 0.02449992062025907
# Model saved! (time elapsed: 612.4624409675598)
# [ Train epoch: 11 ]
# Train accuarcy: 65.94916158026872
# Train average loss: 0.06204513655533276
# [ Validation epoch: 12 ]
# Accuarcy: 90.4608159671265
# Average loss: 0.020604893304943375
# Model saved! (time elapsed: 667.582302570343)
# [ Train epoch: 12 ]
# Train accuarcy: 65.67065598418392
# Train average loss: 0.061924838335024004
# [ Validation epoch: 13 ]
# Accuarcy: 86.93865570883476
# Average loss: 0.028908882925403338
# Model saved! (time elapsed: 722.7005748748779)
# [ Train epoch: 13 ]
# Train accuarcy: 66.25954732784174
# Train average loss: 0.06111294631148116
# [ Validation epoch: 14 ]
# Accuarcy: 89.75638391546815
# Average loss: 0.02548954742795252
# Model saved! (time elapsed: 778.5065121650696)
# [ Train epoch: 14 ]
# Train accuarcy: 65.9729441039384
# Train average loss: 0.06112421805522513
# [ Validation epoch: 15 ]
# Accuarcy: 89.60962723803934
# Average loss: 0.023793114381501987
# Model saved! (time elapsed: 833.562940120697)
# [ Train epoch: 15 ]
# Train accuarcy: 66.14935102894171
# Train average loss: 0.06075620243806014
# [ Validation epoch: 16 ]
# Accuarcy: 88.34751981215145
# Average loss: 0.02825426411551746
# Model saved! (time elapsed: 888.706746339798)
# [ Train epoch: 16 ]
# Train accuarcy: 66.6337557776879
# Train average loss: 0.05986851117200999
# [ Validation epoch: 17 ]
# Accuarcy: 90.25535661872615
# Average loss: 0.026603793160618665
# Model saved! (time elapsed: 944.1506156921387)
# [ Train epoch: 17 ]
# Train accuarcy: 66.63287746645683
# Train average loss: 0.060114852382605395
# [ Validation epoch: 18 ]
# Accuarcy: 89.90314059289697
# Average loss: 0.0218799831643635
# Model saved! (time elapsed: 1000.0595593452454)
# [ Train epoch: 18 ]
# Train accuarcy: 66.73041462526045
# Train average loss: 0.06023417593662655
# [ Validation epoch: 19 ]
# Accuarcy: 87.40827707660698
# Average loss: 0.0280862120604774
# Model saved! (time elapsed: 1055.3029346466064)
# [ Train epoch: 19 ]
# Train accuarcy: 66.49798948420468
# Train average loss: 0.06095483724812187
# [ Validation epoch: 20 ]
# Accuarcy: 89.81508658643968
# Average loss: 0.022093536334983198
# Model saved! (time elapsed: 1110.4860892295837)
# [ Train epoch: 20 ]
# Train accuarcy: 67.30529176234407
# Train average loss: 0.05939662018892673
# [ Validation epoch: 21 ]
# Accuarcy: 88.49427648958027
# Average loss: 0.02468368967178808
# Model saved! (time elapsed: 1166.052493095398)
# [ Train epoch: 21 ]
# Train accuarcy: 68.6228207392228
# Train average loss: 0.05659267784407197
# [ Validation epoch: 22 ]
# Accuarcy: 91.98708541238626
# Average loss: 0.021479883445806786
# Model saved! (time elapsed: 1221.1920247077942)
# [ Train epoch: 22 ]
# Train accuarcy: 68.76699165493719
# Train average loss: 0.05602091770621068
# [ Validation epoch: 23 ]
# Accuarcy: 91.72292339301438
# Average loss: 0.021866239338352213
# Model saved! (time elapsed: 1276.3250918388367)
# [ Train epoch: 23 ]
# Train accuarcy: 68.84154940637853
# Train average loss: 0.055676226002844414
# [ Validation epoch: 24 ]
# Accuarcy: 92.10449075432932
# Average loss: 0.01998877601213108
# Model saved! (time elapsed: 1332.1535341739655)
# [ Train epoch: 24 ]
# Train accuarcy: 69.79142337125107
# Train average loss: 0.0540578358961742
# [ Validation epoch: 25 ]
# Accuarcy: 92.25124743175815
# Average loss: 0.01997634157918925
# Model saved! (time elapsed: 1387.249440908432)
# [ Train epoch: 25 ]
# Train accuarcy: 70.34851687872909
# Train average loss: 0.05345841063663703
# [ Validation epoch: 26 ]
# Accuarcy: 92.3686527737012
# Average loss: 0.01864546373823293
# Model saved! (time elapsed: 1442.5794866085052)
# [ Train epoch: 26 ]
# Train accuarcy: 70.16711581219323
# Train average loss: 0.05405680046503548
# [ Validation epoch: 27 ]
# Accuarcy: 91.9577340769005
# Average loss: 0.02074650343970046
# Model saved! (time elapsed: 1497.9933269023895)
# [ Train epoch: 27 ]
# Train accuarcy: 69.46578061459928
# Train average loss: 0.05439722612789969
# [ Validation epoch: 28 ]
# Accuarcy: 92.33930143821544
# Average loss: 0.018864327047204987
# Model saved! (time elapsed: 1553.5809216499329)
# [ Train epoch: 28 ]
# Train accuarcy: 69.69198712593301
# Train average loss: 0.05437707917184816
# [ Validation epoch: 29 ]
# Accuarcy: 92.01643674787204
# Average loss: 0.018943829415461726
# Model saved! (time elapsed: 1608.8821532726288)
# [ Train epoch: 29 ]
# Train accuarcy: 70.64472807850338
# Train average loss: 0.052609662000952934
# [ Validation epoch: 30 ]
# Accuarcy: 92.30995010272967
# Average loss: 0.018230966117100733
# Model saved! (time elapsed: 1664.173954963684)
# [ Train epoch: 30 ]
# Train accuarcy: 70.60734841573621
# Train average loss: 0.05303221430109804
# [ Validation epoch: 31 ]
# Accuarcy: 92.16319342530085
# Average loss: 0.019579493419092563
# Model saved! (time elapsed: 1719.9514982700348)
# [ Train epoch: 31 ]
# Train accuarcy: 70.1444085220346
# Train average loss: 0.052861310011827735
# [ Validation epoch: 32 ]
# Accuarcy: 92.28059876724392
# Average loss: 0.018902673118968916
# Model saved! (time elapsed: 1775.7200548648834)
# [ Train epoch: 32 ]
# Train accuarcy: 70.20454045515243
# Train average loss: 0.05332664623468351
# [ Validation epoch: 33 ]
# Accuarcy: 92.10449075432932
# Average loss: 0.018408850629220513
# Model saved! (time elapsed: 1831.930111169815)
# [ Train epoch: 33 ]
# Train accuarcy: 70.23980299427188
# Train average loss: 0.05339584559576172
# [ Validation epoch: 34 ]
# Accuarcy: 92.69151746404461
# Average loss: 0.019311379318734855
# Model saved! (time elapsed: 1888.5308253765106)
# [ Train epoch: 34 ]
# Train accuarcy: 70.53093803941367
# Train average loss: 0.052906503228244736
# [ Validation epoch: 35 ]
# Accuarcy: 92.48605811564425
# Average loss: 0.019102263061801534
# Model saved! (time elapsed: 1944.2156846523285)
# [ Train epoch: 35 ]
# Train accuarcy: 70.16310361154986
# Train average loss: 0.05302763273695502
# [ Validation epoch: 36 ]
# Accuarcy: 93.10243616084531
# Average loss: 0.01796779296100402
# Model saved! (time elapsed: 1999.7360281944275)
# [ Train epoch: 36 ]
# Train accuarcy: 70.65107993859756
# Train average loss: 0.05254772932831081
# [ Validation epoch: 37 ]
# Accuarcy: 92.39800410918697
# Average loss: 0.018688121618659816
# Model saved! (time elapsed: 2055.093351840973)
# [ Train epoch: 37 ]
# Train accuarcy: 70.55109284210884
# Train average loss: 0.05307750504592671
# [ Validation epoch: 38 ]
# Accuarcy: 92.30995010272967
# Average loss: 0.018603608832266243
# Model saved! (time elapsed: 2111.112461090088)
# [ Train epoch: 38 ]
# Train accuarcy: 70.69561070264797
# Train average loss: 0.0525356209719007
# [ Validation epoch: 39 ]
# Accuarcy: 92.04578808335779
# Average loss: 0.019369706791413647
# Model saved! (time elapsed: 2166.451093673706)
# [ Train epoch: 39 ]
# Train accuarcy: 70.90510376674462
# Train average loss: 0.052014449420079906
# [ Validation epoch: 40 ]
# Accuarcy: 92.51540945113003
# Average loss: 0.017877935341963642
# Model saved! (time elapsed: 2221.6800479888916)
# [ Train epoch: 40 ]
# Train accuarcy: 71.2571447028647
# Train average loss: 0.051567070057651584
# [ Validation epoch: 41 ]
# Accuarcy: 92.75022013501615
# Average loss: 0.017492188094279475
# Model saved! (time elapsed: 2278.0259075164795)
# [ Train epoch: 41 ]
# Train accuarcy: 71.0899883519227
# Train average loss: 0.05170070172370972
# [ Validation epoch: 42 ]
# Accuarcy: 92.3686527737012
# Average loss: 0.01927545820429838
# Model saved! (time elapsed: 2333.422054052353)
# [ Train epoch: 42 ]
# Train accuarcy: 70.76141713807966
# Train average loss: 0.051806512565883804
# [ Validation epoch: 43 ]
# Accuarcy: 93.16113883181684
# Average loss: 0.017753821890883197
# Model saved! (time elapsed: 2388.8356852531433)
# [ Train epoch: 43 ]
# Train accuarcy: 70.89209736960451
# Train average loss: 0.05172088989934524
# [ Validation epoch: 44 ]
# Accuarcy: 93.19049016730261
# Average loss: 0.01711378027861301
# Model saved! (time elapsed: 2443.9774487018585)
# [ Train epoch: 44 ]
# Train accuarcy: 71.60197950055459
# Train average loss: 0.05078227554587439
# [ Validation epoch: 45 ]
# Accuarcy: 93.07308482535956
# Average loss: 0.01782771153580523
# Model saved! (time elapsed: 2500.509936571121)
# [ Train epoch: 45 ]
# Train accuarcy: 70.74205607110073
# Train average loss: 0.051940301316337506
# [ Validation epoch: 46 ]
# Accuarcy: 93.04373348987379
# Average loss: 0.017507555751041966
# Model saved! (time elapsed: 2555.7301576137543)
# [ Train epoch: 46 ]
# Train accuarcy: 71.29756874272827
# Train average loss: 0.05132638777488569
# [ Validation epoch: 47 ]
# Accuarcy: 93.10243616084531
# Average loss: 0.017423365959454255
# Model saved! (time elapsed: 2610.73379945755)
# [ Train epoch: 47 ]
# Train accuarcy: 71.63791816896959
# Train average loss: 0.051073020903530726
# [ Validation epoch: 48 ]
# Accuarcy: 92.83827414147343
# Average loss: 0.017956769718762047
# Model saved! (time elapsed: 2666.452909708023)
# [ Train epoch: 48 ]
# Train accuarcy: 71.0445267149188
# Train average loss: 0.05165174641953514
# [ Validation epoch: 49 ]
# Accuarcy: 92.42735544467273
# Average loss: 0.01873997728129024
# Model saved! (time elapsed: 2721.3530695438385)
# [ Train epoch: 49 ]
# Train accuarcy: 70.51435283089747
# Train average loss: 0.052014358274443465
# [ Validation epoch: 50 ]
# Accuarcy: 93.10243616084531
# Average loss: 0.01752975656991835
# Model saved! (time elapsed: 2776.426960706711)
# [ Train epoch: 50 ]
# Train accuarcy: 71.79542674067727
# Train average loss: 0.05050117649488441
# [ Validation epoch: 51 ]
# Accuarcy: 93.04373348987379
# Average loss: 0.01763220619282346
# Model saved! (time elapsed: 2832.069723367691)
# [ Train epoch: 51 ]
# Train accuarcy: 70.82748313558689
# Train average loss: 0.05145630822183801
# [ Validation epoch: 52 ]
# Accuarcy: 92.92632814793073
# Average loss: 0.017846508738334696
# Model saved! (time elapsed: 2886.9315037727356)
# [ Train epoch: 52 ]
# Train accuarcy: 71.52500821322293
# Train average loss: 0.05080015146632603
# [ Validation epoch: 53 ]
# Accuarcy: 92.83827414147343
# Average loss: 0.019036136652879572
# Model saved! (time elapsed: 2941.823383331299)
# [ Train epoch: 53 ]
# Train accuarcy: 71.59416276032051
# Train average loss: 0.05047063186623655
# [ Validation epoch: 54 ]
# Accuarcy: 92.72086879953038
# Average loss: 0.01761943635910461
# Model saved! (time elapsed: 2997.193354845047)
# [ Train epoch: 54 ]
# Train accuarcy: 71.05981270326893
# Train average loss: 0.05151037561938953
# [ Validation epoch: 55 ]
# Accuarcy: 92.8676254769592
# Average loss: 0.018268543326998163
# Model saved! (time elapsed: 3053.431838989258)
# [ Train epoch: 55 ]
# Train accuarcy: 71.4766439155999
# Train average loss: 0.05102633491815681
# [ Validation epoch: 56 ]
# Accuarcy: 92.42735544467273
# Average loss: 0.017907040290444837
# Model saved! (time elapsed: 3108.826173067093)
# [ Train epoch: 56 ]
# Train accuarcy: 71.33987280100645
# Train average loss: 0.0504780367307664
# [ Validation epoch: 57 ]
# Accuarcy: 92.83827414147343
# Average loss: 0.017849946854346863
# Model saved! (time elapsed: 3164.4796917438507)
# [ Train epoch: 57 ]
# Train accuarcy: 71.47180313341563
# Train average loss: 0.05091342749883977
# [ Validation epoch: 58 ]
# Accuarcy: 92.42735544467273
# Average loss: 0.018129349325649333
# Model saved! (time elapsed: 3220.740882873535)
# [ Train epoch: 58 ]
# Train accuarcy: 71.82282474944789
# Train average loss: 0.050284433983353284
# [ Validation epoch: 59 ]
# Accuarcy: 93.07308482535956
# Average loss: 0.01700259248488524
# Model saved! (time elapsed: 3276.257176399231)
# [ Train epoch: 59 ]
# Train accuarcy: 70.83127631358765
# Train average loss: 0.051607856980911165
# [ Validation epoch: 60 ]
# Accuarcy: 93.10243616084531
# Average loss: 0.017830069991179077
# Model saved! (time elapsed: 3331.561295747757)
# [ Train epoch: 60 ]
# Train accuarcy: 71.49504988486666
# Train average loss: 0.05070742586720687
# [ Validation epoch: 61 ]
# Accuarcy: 92.63281479307308
# Average loss: 0.01843666858448463
# Model saved! (time elapsed: 3387.5623128414154)
# [ Train epoch: 61 ]
# Train accuarcy: 70.99274770111982
# Train average loss: 0.051379752930475454
# [ Validation epoch: 62 ]
# Accuarcy: 92.92632814793073
# Average loss: 0.018241556676770014
# Model saved! (time elapsed: 3442.755604982376)
# [ Train epoch: 62 ]
# Train accuarcy: 71.6931947795943
# Train average loss: 0.05054296491352016
# [ Validation epoch: 63 ]
# Accuarcy: 92.48605811564425
# Average loss: 0.01827953695061272
# Model saved! (time elapsed: 3497.8798298835754)
# [ Train epoch: 63 ]
# Train accuarcy: 72.03248671065361
# Train average loss: 0.05053529048198701
# [ Validation epoch: 64 ]
# Accuarcy: 92.8676254769592
# Average loss: 0.01769903446087083
# Model saved! (time elapsed: 3552.957516670227)
# [ Train epoch: 64 ]
# Train accuarcy: 72.40931557548592
# Train average loss: 0.04966376240335067
# [ Validation epoch: 65 ]
# Accuarcy: 93.07308482535956
# Average loss: 0.016727871705193235
# Model saved! (time elapsed: 3608.7536811828613)
# [ Train epoch: 65 ]
# Train accuarcy: 72.07565634999416
# Train average loss: 0.05038863538803442
# [ Validation epoch: 66 ]
# Accuarcy: 92.83827414147343
# Average loss: 0.0173625016657705
# Model saved! (time elapsed: 3663.988692522049)
# [ Train epoch: 66 ]
# Train accuarcy: 71.48958104864991
# Train average loss: 0.05090218122988128
# [ Validation epoch: 67 ]
# Accuarcy: 93.19049016730261
# Average loss: 0.01742862762420241
# Model saved! (time elapsed: 3719.2035627365112)
# [ Train epoch: 67 ]
# Train accuarcy: 72.01154114221663
# Train average loss: 0.05002807704315607
# [ Validation epoch: 68 ]
# Accuarcy: 92.83827414147343
# Average loss: 0.018016061082696648
# Model saved! (time elapsed: 3774.965630054474)
# [ Train epoch: 68 ]
# Train accuarcy: 71.21207097035912
# Train average loss: 0.05099756835167814
# [ Validation epoch: 69 ]
# Accuarcy: 92.66216612855885
# Average loss: 0.01788498619792746
# Model saved! (time elapsed: 3829.986988544464)
# [ Train epoch: 69 ]
# Train accuarcy: 71.26730253932142
# Train average loss: 0.05133518028613135
# [ Validation epoch: 70 ]
# Accuarcy: 93.13178749633109
# Average loss: 0.017521476470937748
# Model saved! (time elapsed: 3885.251713514328)
# [ Train epoch: 70 ]
# Train accuarcy: 71.57254142915153
# Train average loss: 0.050775398207820066
# [ Validation epoch: 71 ]
# Accuarcy: 92.69151746404461
# Average loss: 0.017858752316574144
# Model saved! (time elapsed: 3940.4492058753967)
# [ Train epoch: 71 ]
# Train accuarcy: 71.50012985934808
# Train average loss: 0.050852829095219765
# [ Validation epoch: 72 ]
# Accuarcy: 93.01438215438803
# Average loss: 0.017324600187230046
# Model saved! (time elapsed: 3996.279352903366)
# [ Train epoch: 72 ]
# Train accuarcy: 72.05052536838744
# Train average loss: 0.05033623041583584
# [ Validation epoch: 73 ]
# Accuarcy: 92.80892280598768
# Average loss: 0.01820579964130688
# Model saved! (time elapsed: 4051.6432688236237)
# [ Train epoch: 73 ]
# Train accuarcy: 71.96112633651008
# Train average loss: 0.049844927049710185
# [ Validation epoch: 74 ]
# Accuarcy: 93.16113883181684
# Average loss: 0.01764182510668489
# Model saved! (time elapsed: 4106.803374528885)
# [ Train epoch: 74 ]
# Train accuarcy: 71.4275855978096
# Train average loss: 0.051256057329614205
# [ Validation epoch: 75 ]
# Accuarcy: 92.69151746404461
# Average loss: 0.017900601274322688
# Model saved! (time elapsed: 4162.6304614543915)
# [ Train epoch: 75 ]
# Train accuarcy: 71.06946872627496
# Train average loss: 0.05126683977245628
# [ Validation epoch: 76 ]
# Accuarcy: 92.7795714705019
# Average loss: 0.017092570257932167
# Model saved! (time elapsed: 4217.921008110046)
# [ Train epoch: 76 ]
# Train accuarcy: 71.47302371070346
# Train average loss: 0.05059422621804322
# [ Validation epoch: 77 ]
# Accuarcy: 93.27854417375991
# Average loss: 0.01768741749679724
# Model saved! (time elapsed: 4273.080420732498)
# [ Train epoch: 77 ]
# Train accuarcy: 71.76373904052137
# Train average loss: 0.04992720342304856
# [ Validation epoch: 78 ]
# Accuarcy: 93.04373348987379
# Average loss: 0.017322953332282245
# Model saved! (time elapsed: 4329.077807188034)
# [ Train epoch: 78 ]
# Train accuarcy: 72.11079998801583
# Train average loss: 0.049991814997953424
# [ Validation epoch: 79 ]
# Accuarcy: 92.72086879953038
# Average loss: 0.01796033882131701
# Model saved! (time elapsed: 4384.736798286438)
# [ Train epoch: 79 ]
# Train accuarcy: 71.67627110468236
# Train average loss: 0.05061541641120245
# [ Validation epoch: 80 ]
# Accuarcy: 92.8676254769592
# Average loss: 0.01798047013810418
# Model saved! (time elapsed: 4440.018003940582)
# [ Train epoch: 80 ]
# Train accuarcy: 72.12470737392152
# Train average loss: 0.05018329438839881
# [ Validation epoch: 81 ]
# Accuarcy: 92.7795714705019
# Average loss: 0.018224347910906935
# Model saved! (time elapsed: 4495.355546951294)
# [ Train epoch: 81 ]
# Train accuarcy: 72.07233471755691
# Train average loss: 0.05018893179008106
# [ Validation epoch: 82 ]
# Accuarcy: 93.30789550924567
# Average loss: 0.017886331378713816
# Model saved! (time elapsed: 4551.3665606975555)
# [ Train epoch: 82 ]
# Train accuarcy: 72.75282065066597
# Train average loss: 0.04935129489354642
# [ Validation epoch: 83 ]
# Accuarcy: 92.92632814793073
# Average loss: 0.01870658172560746
# Model saved! (time elapsed: 4606.660834789276)
# [ Train epoch: 83 ]
# Train accuarcy: 72.11107417607465
# Train average loss: 0.049952723007148085
# [ Validation epoch: 84 ]
# Accuarcy: 92.8676254769592
# Average loss: 0.018566311313271838
# Model saved! (time elapsed: 4661.834222316742)
# [ Train epoch: 84 ]
# Train accuarcy: 72.6956554783236
# Train average loss: 0.04927081282581299
# [ Validation epoch: 85 ]
# Accuarcy: 93.27854417375991
# Average loss: 0.017152564747175372
# Model saved! (time elapsed: 4717.686483860016)
# [ Train epoch: 85 ]
# Train accuarcy: 72.07469443598697
# Train average loss: 0.049965337751533175
# [ Validation epoch: 86 ]
# Accuarcy: 92.98503081890226
# Average loss: 0.017339971766098874
# Model saved! (time elapsed: 4772.91401553154)
# [ Train epoch: 86 ]
# Train accuarcy: 72.03655084616867
# Train average loss: 0.05013399925584566
# [ Validation epoch: 87 ]
# Accuarcy: 93.07308482535956
# Average loss: 0.017326470229382177
# Model saved! (time elapsed: 4828.146863222122)
# [ Train epoch: 87 ]
# Train accuarcy: 71.71096976647662
# Train average loss: 0.051026733183866024
# [ Validation epoch: 88 ]
# Accuarcy: 93.33724684473144
# Average loss: 0.01686320727019146
# Model saved! (time elapsed: 4883.320849895477)
# [ Train epoch: 88 ]
# Train accuarcy: 72.40143877701624
# Train average loss: 0.04960204626392477
# [ Validation epoch: 89 ]
# Accuarcy: 93.10243616084531
# Average loss: 0.017658394429256465
# Model saved! (time elapsed: 4939.154965400696)
# [ Train epoch: 89 ]
# Train accuarcy: 71.63233198330687
# Train average loss: 0.05030587349895372
# [ Validation epoch: 90 ]
# Accuarcy: 92.51540945113003
# Average loss: 0.01904699883399417
# Model saved! (time elapsed: 4994.487919330597)
# [ Train epoch: 90 ]
# Train accuarcy: 71.79729684946565
# Train average loss: 0.050147124828920156
# [ Validation epoch: 91 ]
# Accuarcy: 93.01438215438803
# Average loss: 0.01762340302678333
# Model saved! (time elapsed: 5049.803470849991)
# [ Train epoch: 91 ]
# Train accuarcy: 71.81009566487299
# Train average loss: 0.05011513708945966
# [ Validation epoch: 92 ]
# Accuarcy: 93.39594951570297
# Average loss: 0.016866514123024954
# Model saved! (time elapsed: 5105.64990401268)
# [ Train epoch: 92 ]
# Train accuarcy: 71.03674570981141
# Train average loss: 0.051151556231383837
# [ Validation epoch: 93 ]
# Accuarcy: 93.16113883181684
# Average loss: 0.017399289300006473
# Model saved! (time elapsed: 5160.786869049072)
# [ Train epoch: 93 ]
# Train accuarcy: 71.85058602878217
# Train average loss: 0.050403057184985334
# [ Validation epoch: 94 ]
# Accuarcy: 92.69151746404461
# Average loss: 0.01722177212097304
# Model saved! (time elapsed: 5216.301066875458)
# [ Train epoch: 94 ]
# Train accuarcy: 71.72048824174433
# Train average loss: 0.05069157758396475
# [ Validation epoch: 95 ]
# Accuarcy: 93.19049016730261
# Average loss: 0.017358503828991324
# Model saved! (time elapsed: 5271.555883646011)
# [ Train epoch: 95 ]
# Train accuarcy: 72.67903074594365
# Train average loss: 0.04914311187439815
# [ Validation epoch: 96 ]
# Accuarcy: 93.10243616084531
# Average loss: 0.0168874004316148
# Model saved! (time elapsed: 5327.840070962906)
# [ Train epoch: 96 ]
# Train accuarcy: 71.71256315136938
# Train average loss: 0.050196154538845204
# [ Validation epoch: 97 ]
# Accuarcy: 92.92632814793073
# Average loss: 0.018580505334109827
# Model saved! (time elapsed: 5383.58642077446)
# [ Train epoch: 97 ]
# Train accuarcy: 72.18785058315754
# Train average loss: 0.049678618877463485
# [ Validation epoch: 98 ]
# Accuarcy: 92.83827414147343
# Average loss: 0.0179088325935408
# Model saved! (time elapsed: 5441.012862205505)
# [ Train epoch: 98 ]
# Train accuarcy: 71.08394046056175
# Train average loss: 0.05109600492279397
# [ Validation epoch: 99 ]
# Accuarcy: 93.3665981802172
# Average loss: 0.01676756616803184
# Model saved! (time elapsed: 5497.443081855774)
# [ Train epoch: 99 ]
# Train accuarcy: 71.58408327900791
# Train average loss: 0.05013178734101561
# [ Validation epoch: 100 ]
# Accuarcy: 93.04373348987379
# Average loss: 0.016944201143214106
# Model saved! (time elapsed: 5552.724598646164)

# %%
net = torchvision.models.resnet50(pretrained=True)
num_features = net.fc.in_features
net.fc = nn.Linear(num_features, 6)
net.to(device)
file_name = "./models/SceneClassification/Mymodel2_new.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])
# Out:
# <All keys matched successfully>

# %%
import pandas as pd
import seaborn as sns


# 네트워크에 데이터셋을 입력하여 혼동 행렬(confusion matrix)을 계산하는 함수
def get_confusion_matrix(net, num_classes, data_loader):
    net.eval() # 모델을 평가 모드로 설정
    confusion_matrix = torch.zeros(num_classes, num_classes, dtype=torch.int32)

    for batch_idx, (inputs, targets) in enumerate(data_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        outputs = net(inputs)
        _, predicted = outputs.max(1)

        for t, p in zip(targets.view(-1), predicted.view(-1)):
            confusion_matrix[t.long(), p.long()] += 1

    return confusion_matrix



# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader_transferred)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.9044, 0.9907, 0.8670, 0.9332, 0.9750, 0.9746])
# [ 전체 평균 정확도 ]
# tensor(0.9404)
